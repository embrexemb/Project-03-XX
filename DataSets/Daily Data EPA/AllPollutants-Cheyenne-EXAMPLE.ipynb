# %%
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2016 Data

# %%
#files to load for 2016
Cheyenne_CO_2016 = "CO-CarbonMonoxide/2016-Cheyenne-CO.csv"
Cheyenne_NO_2016 = "NitrogenDioxide/2016-Cheyenne-NO2.csv"
Cheyenne_O_2016 = "Ozone/2016-Cheyenne-Ozone.csv"
#no lead for Cheyenne
Cheyenne_PM_2016 = "PM-ParticulateMatter/2016-Cheyenne-PM10.csv"
Cheyenne_SO_2016 = "SulfurDioxide/2016-Cheyenne-SO2.csv"

#Read files into Pandas dataframe

df_2016_CO = pd.read_csv(Cheyenne_CO_2016)
df_2016_NO = pd.read_csv(Cheyenne_NO_2016)
df_2016_O = pd.read_csv(Cheyenne_O_2016)
df_2016_PM = pd.read_csv(Cheyenne_PM_2016)
df_2016_SO = pd.read_csv(Cheyenne_SO_2016)


df_2016_PM=df_2016_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2016_CO=df_2016_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_NO=df_2016_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_O=df_2016_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_SO=df_2016_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]


df_2016_PM
# Out:
#                Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0    Cheyenne SLAMS site    1/1/2016                              3  ug/m3 SC
# 1    Cheyenne SLAMS site    1/7/2016                              7  ug/m3 SC
# 2    Cheyenne SLAMS site   1/13/2016                              3  ug/m3 SC
# 3    Cheyenne SLAMS site   1/19/2016                              3  ug/m3 SC
# 4    Cheyenne SLAMS site   1/25/2016                              2  ug/m3 SC
# ..                   ...         ...                            ...       ...
# 753       Cheyenne NCore  12/27/2016                              9  ug/m3 SC
# 754       Cheyenne NCore  12/28/2016                              5  ug/m3 SC
# 755       Cheyenne NCore  12/29/2016                              8  ug/m3 SC
# 756       Cheyenne NCore  12/30/2016                              6  ug/m3 SC
# 757       Cheyenne NCore  12/31/2016                              9  ug/m3 SC
#
#      DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# 0                  3      41.136846     -104.818240
# 1                  6      41.136846     -104.818240
# 2                  3      41.136846     -104.818240
# 3                  3      41.136846     -104.818240
# 4                  2      41.136846     -104.818240
# ..               ...            ...             ...
# 753                8      41.182227     -104.778334
# 754                5      41.182227     -104.778334
# 755                7      41.182227     -104.778334
# 756                6      41.182227     -104.778334
# 757                8      41.182227     -104.778334
#
# [758 rows x 7 columns]

# %% [markdown]
# print(df_2016_O.count())
# print(df_2016_CO.count())
# print(df_2016_NO.count())
# print(df_2016_PM.count())
# print(df_2016_SO.count())

# %% [markdown]
# Scratched
# #Cheyenne_2016_All = left.join(right, on=['Site Name'])
# #Cheyenne_2016_All = pd.concat([left, right], axis=1)
# #Cheyenne_2016_All = pd.merge(left.drop_duplicates(),right, how='inner', on='Site Name', validate='many_to_many')
# #C_2016=pd.merge(left.drop_duplicates(), right, how = 'inner',on=['col_1','col_2'])
# #C_2016=pd.concat([left, right],axis=1 )

# %%
left = df_2016_PM
right = df_2016_NO
Cheyenne_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = Cheyenne_2016_All
right = df_2016_O
Cheyenne_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Cheyenne_2016_All
right = df_2016_SO
Cheyenne_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Cheyenne_2016_All
right = df_2016_CO
Cheyenne_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
Cheyenne_2016_All.columns
# Out:
# Index(['Site Name', 'Date', 'Daily Mean PM10 Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'SITE_LATITUDE', 'SITE_LONGITUDE',
#        'Daily Max 1-hour NO2 Concentration', 'UNITS_y', 'DAILY_AQI_VALUE_y',
#        '_merge', 'Daily Max 8-hour Ozone Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'Daily Max 1-hour SO2 Concentration', 'UNITS_y',
#        'DAILY_AQI_VALUE_y', 'Daily Max 8-hour CO Concentration', 'UNITS',
#        'DAILY_AQI_VALUE'],
#       dtype='object')

# %%
Cheyenne_2016_All.count()
# Out:
# Site Name                               794
# Date                                    794
# Daily Mean PM10 Concentration           758
# UNITS_x                                 758
# DAILY_AQI_VALUE_x                       758
# SITE_LATITUDE                           758
# SITE_LONGITUDE                          758
# Daily Max 1-hour NO2 Concentration      603
# UNITS_y                                 603
# DAILY_AQI_VALUE_y                       603
# _merge                                  794
# Daily Max 8-hour Ozone Concentration    601
# UNITS_x                                 601
# DAILY_AQI_VALUE_x                       601
# Daily Max 1-hour SO2 Concentration      569
# UNITS_y                                 569
# DAILY_AQI_VALUE_y                       569
# Daily Max 8-hour CO Concentration       272
# UNITS                                   272
# DAILY_AQI_VALUE                         272
# dtype: int64

# %%
#print(Cheyenne_2016_All)

# %%
Cheyenne_2016_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
Cheyenne_2016_All.count()
# Out:
# Site Name      794
# Date           794
# DMean PM10     758
# PM10 Units     758
# PM10 AQI       758
# Lat            758
# Lng            758
# DMax NO2       603
# NO2 Units      603
# NO2 AQI        603
# Merged         794
# DMax Ozone     601
# Ozone Units    601
# Ozone AQI      601
# DMax SO2       569
# SO2 Units      569
# SO2 AQI        569
# DMax CO        272
# CO Units       272
# CO AQI         272
# dtype: int64

# %%
Cheyenne_2016_All.drop('Merged',axis=1,inplace=True)
Cheyenne_2016_All.to_csv("CH2016DF.csv")

# %% [markdown]
# 2018 Data

# %%
#files to load for 2018

Cheyenne_CO_2018 = "CO-CarbonMonoxide/2018-Cheyenne-CO.csv"
Cheyenne_NO_2018 = "NitrogenDioxide/2018-Cheyenne-NO2.csv"
Cheyenne_O_2018= "Ozone/2018-Cheyenne-Ozone.csv"
#no lead for Cheyenne
Cheyenne_PM_2018 = "PM-ParticulateMatter/2018-Cheyenne-PM10.csv"
Cheyenne_SO_2018 = "SulfurDioxide/2018-Cheyenne-SO2.csv"

#Read files into Pandas dataframe

df_2018_CO = pd.read_csv(Cheyenne_CO_2018)
df_2018_NO = pd.read_csv(Cheyenne_NO_2018)
df_2018_O = pd.read_csv(Cheyenne_O_2018)
df_2018_PM = pd.read_csv(Cheyenne_PM_2018)
df_2018_SO = pd.read_csv(Cheyenne_SO_2018)

df_2018_PM=df_2018_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2018_CO=df_2018_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_NO=df_2018_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_O=df_2018_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_SO=df_2018_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]


df_2018_PM
# Out:
#                Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0    Cheyenne SLAMS site    1/2/2018                             12  ug/m3 SC
# 1    Cheyenne SLAMS site    1/8/2018                             14  ug/m3 SC
# 2    Cheyenne SLAMS site   1/14/2018                              3  ug/m3 SC
# 3    Cheyenne SLAMS site   1/20/2018                              3  ug/m3 SC
# 4    Cheyenne SLAMS site   1/26/2018                              4  ug/m3 SC
# ..                   ...         ...                            ...       ...
# 563       Cheyenne NCore  12/27/2018                              3  ug/m3 SC
# 564       Cheyenne NCore  12/28/2018                              9  ug/m3 SC
# 565       Cheyenne NCore  12/29/2018                             11  ug/m3 SC
# 566       Cheyenne NCore  12/30/2018                              5  ug/m3 SC
# 567       Cheyenne NCore  12/31/2018                             13  ug/m3 SC
#
#      DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# 0                 11      41.136846     -104.818240
# 1                 13      41.136846     -104.818240
# 2                  3      41.136846     -104.818240
# 3                  3      41.136846     -104.818240
# 4                  4      41.136846     -104.818240
# ..               ...            ...             ...
# 563                3      41.182227     -104.778334
# 564                8      41.182227     -104.778334
# 565               10      41.182227     -104.778334
# 566                5      41.182227     -104.778334
# 567               12      41.182227     -104.778334
#
# [568 rows x 7 columns]

# %%
Cheyenne_2018_All=[]

# %%
left = df_2018_PM
right = df_2018_NO
Cheyenne_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = Cheyenne_2018_All
right = df_2018_O
Cheyenne_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Cheyenne_2018_All
right = df_2018_SO
Cheyenne_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Cheyenne_2018_All
right = df_2018_CO
Cheyenne_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
Cheyenne_2018_All.columns
# Out:
# Index(['Site Name', 'Date', 'Daily Mean PM10 Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'SITE_LATITUDE', 'SITE_LONGITUDE',
#        'Daily Max 1-hour NO2 Concentration', 'UNITS_y', 'DAILY_AQI_VALUE_y',
#        '_merge', 'Daily Max 8-hour Ozone Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'Daily Max 1-hour SO2 Concentration', 'UNITS_y',
#        'DAILY_AQI_VALUE_y', 'Daily Max 8-hour CO Concentration', 'UNITS',
#        'DAILY_AQI_VALUE'],
#       dtype='object')

# %%
Cheyenne_2018_All.count()
# Out:
# Site Name                               589
# Date                                    589
# Daily Mean PM10 Concentration           568
# UNITS_x                                 568
# DAILY_AQI_VALUE_x                       568
# SITE_LATITUDE                           568
# SITE_LONGITUDE                          568
# Daily Max 1-hour NO2 Concentration      421
# UNITS_y                                 421
# DAILY_AQI_VALUE_y                       421
# _merge                                  580
# Daily Max 8-hour Ozone Concentration    421
# UNITS_x                                 421
# DAILY_AQI_VALUE_x                       421
# Daily Max 1-hour SO2 Concentration      390
# UNITS_y                                 390
# DAILY_AQI_VALUE_y                       390
# Daily Max 8-hour CO Concentration       341
# UNITS                                   341
# DAILY_AQI_VALUE                         341
# dtype: int64

# %%
Cheyenne_2018_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
Cheyenne_2018_All.drop('Merged',axis=1,inplace=True)
Cheyenne_2018_All.to_csv("CH2018DF.csv")

# %% [markdown]
# 2020 Data

# %%
#files to load for 2020

Cheyenne_CO_2020 = "CO-CarbonMonoxide/2020-Cheyenne-CO.csv"
Cheyenne_NO_2020 = "NitrogenDioxide/2020-Cheyenne-NO2.csv"
Cheyenne_O_2020 = "Ozone/2020-Cheyenne-Ozone.csv"
#no lead for Cheyenne
Cheyenne_PM_2020 = "PM-ParticulateMatter/2020-Cheyenne-PM10.csv"
Cheyenne_SO_2020 = "SulfurDioxide/2020-Cheyenne-SO2.csv"

#Read files into Pandas dataframe

df_2020_CO = pd.read_csv(Cheyenne_CO_2020)
df_2020_NO = pd.read_csv(Cheyenne_NO_2020)
df_2020_O = pd.read_csv(Cheyenne_O_2020)
df_2020_PM = pd.read_csv(Cheyenne_PM_2020)
df_2020_SO = pd.read_csv(Cheyenne_SO_2020)


df_2020_PM=df_2020_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2020_CO=df_2020_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_NO=df_2020_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_O=df_2020_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_SO=df_2020_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]


df_2020_PM
# Out:
#                Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0    Cheyenne SLAMS site    1/4/2020                              3  ug/m3 SC
# 1    Cheyenne SLAMS site   1/10/2020                              6  ug/m3 SC
# 2    Cheyenne SLAMS site   1/16/2020                             27  ug/m3 SC
# 3    Cheyenne SLAMS site   1/22/2020                              6  ug/m3 SC
# 4    Cheyenne SLAMS site   1/28/2020                              3  ug/m3 SC
# ..                   ...         ...                            ...       ...
# 608       Cheyenne NCore  12/27/2020                              1  ug/m3 SC
# 609       Cheyenne NCore  12/28/2020                              4  ug/m3 SC
# 610       Cheyenne NCore  12/29/2020                              2  ug/m3 SC
# 611       Cheyenne NCore  12/30/2020                              4  ug/m3 SC
# 612       Cheyenne NCore  12/31/2020                              3  ug/m3 SC
#
#      DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# 0                  3      41.136846     -104.818240
# 1                  6      41.136846     -104.818240
# 2                 25      41.136846     -104.818240
# 3                  6      41.136846     -104.818240
# 4                  3      41.136846     -104.818240
# ..               ...            ...             ...
# 608                1      41.182227     -104.778334
# 609                4      41.182227     -104.778334
# 610                2      41.182227     -104.778334
# 611                4      41.182227     -104.778334
# 612                3      41.182227     -104.778334
#
# [613 rows x 7 columns]

# %%
Cheyenne_2020_All = []
df_2020_CO
# Out:
#           Site Name        Date  Daily Max 8-hour CO Concentration UNITS  \
# 0    Cheyenne NCore    1/1/2020                                0.1   ppm
# 1    Cheyenne NCore    1/2/2020                                0.1   ppm
# 2    Cheyenne NCore    1/3/2020                                0.1   ppm
# 3    Cheyenne NCore    1/4/2020                                0.1   ppm
# 4    Cheyenne NCore    1/5/2020                                0.1   ppm
# ..              ...         ...                                ...   ...
# 336  Cheyenne NCore  12/27/2020                                0.1   ppm
# 337  Cheyenne NCore  12/28/2020                                0.1   ppm
# 338  Cheyenne NCore  12/29/2020                                0.1   ppm
# 339  Cheyenne NCore  12/30/2020                                0.1   ppm
# 340  Cheyenne NCore  12/31/2020                                0.1   ppm
#
#      DAILY_AQI_VALUE
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ..               ...
# 336                1
# 337                1
# 338                1
# 339                1
# 340                1
#
# [341 rows x 5 columns]

# %%
left = df_2020_PM
right = df_2020_NO
Cheyenne_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = Cheyenne_2020_All
right = df_2020_O
Cheyenne_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Cheyenne_2020_All
right = df_2020_SO
Cheyenne_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Cheyenne_2020_All
right = df_2020_CO
Cheyenne_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
Cheyenne_2020_All.count()
# Out:
# Site Name                               623
# Date                                    623
# Daily Mean PM10 Concentration           613
# UNITS_x                                 613
# DAILY_AQI_VALUE_x                       613
# SITE_LATITUDE                           613
# SITE_LONGITUDE                          613
# Daily Max 1-hour NO2 Concentration      501
# UNITS_y                                 501
# DAILY_AQI_VALUE_y                       501
# _merge                                  622
# Daily Max 8-hour Ozone Concentration    522
# UNITS_x                                 522
# DAILY_AQI_VALUE_x                       522
# Daily Max 1-hour SO2 Concentration      495
# UNITS_y                                 495
# DAILY_AQI_VALUE_y                       495
# Daily Max 8-hour CO Concentration       341
# UNITS                                   341
# DAILY_AQI_VALUE                         341
# dtype: int64

# %%
Cheyenne_2020_All.tail()
# Out:
#                  Site Name       Date  Daily Mean PM10 Concentration UNITS_x  \
# 618  Laramie County Mobile   5/6/2020                            NaN     NaN
# 619  Laramie County Mobile  6/14/2020                            NaN     NaN
# 620         Cheyenne NCore   2/4/2020                            NaN     NaN
# 621         Cheyenne NCore   2/5/2020                            NaN     NaN
# 622  Laramie County Mobile   7/1/2020                            NaN     NaN
#
#      DAILY_AQI_VALUE_x  SITE_LATITUDE  SITE_LONGITUDE  \
# 618                NaN            NaN             NaN
# 619                NaN            NaN             NaN
# 620                NaN            NaN             NaN
# 621                NaN            NaN             NaN
# 622                NaN            NaN             NaN
#
#      Daily Max 1-hour NO2 Concentration UNITS_y  DAILY_AQI_VALUE_y  \
# 618                                 2.4     ppb                2.0
# 619                                 5.7     ppb                5.0
# 620                                16.1     ppb               15.0
# 621                                20.1     ppb               19.0
# 622                                 NaN     NaN                NaN
#
#          _merge  Daily Max 8-hour Ozone Concentration UNITS_x  \
# 618  right_only                                 0.052     ppm
# 619  right_only                                 0.058     ppm
# 620  right_only                                 0.034     ppm
# 621  right_only                                 0.037     ppm
# 622         NaN                                 0.058     ppm
#
#      DAILY_AQI_VALUE_x  Daily Max 1-hour SO2 Concentration UNITS_y  \
# 618               48.0                                -0.1     ppb
# 619               61.0                                -0.1     ppb
# 620               31.0                                -0.2     ppb
# 621               34.0                                 0.5     ppb
# 622               61.0                                 NaN     NaN
#
#      DAILY_AQI_VALUE_y  Daily Max 8-hour CO Concentration UNITS  \
# 618                0.0                                NaN   NaN
# 619                0.0                                NaN   NaN
# 620                0.0                                0.2   ppm
# 621                0.0                                0.2   ppm
# 622                NaN                                NaN   NaN
#
#      DAILY_AQI_VALUE
# 618              NaN
# 619              NaN
# 620              2.0
# 621              2.0
# 622              NaN

# %%
Cheyenne_2020_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
Cheyenne_2020_All.columns

# %%
Cheyenne_2020_All.drop('Merged',axis=1,inplace=True)
Cheyenne_2020_All.to_csv("CH2020DF.csv")

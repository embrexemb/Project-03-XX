# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_df=pd.read_csv("../output_data/Weather.csv")
weather_df
# Out:
#      Unnamed: 0  City ID               City Country      Lat       Lon  \
# 0             0  2155415        New Norfolk      AU -42.7826  147.0587
# 1             1  3366880           Hermanus      ZA -34.4187   19.2345
# 2             2  2068110          Kununurra      AU -15.7667  128.7333
# 3             3  5850554      Makakilo City      US  21.3469 -158.0858
# 4             4  5847411            Kahului      US  20.8947 -156.4700
# ..          ...      ...                ...     ...      ...       ...
# 574         574  1633070          Palembang      ID  -2.9167  104.7458
# 575         575  2012938  Yerofey Pavlovich      RU  53.9667  121.9667
# 576         576  3374083          Bathsheba      BB  13.2167  -59.5167
# 577         577  3430708           Mercedes      AR -34.6515  -59.4307
# 578         578  2649715           Falmouth      GB  50.1544   -5.0711
#
#      Cloudiness  Humidity  Max Temp  Wind Speed                 Date
# 0            99        78     50.38        1.55  2021-04-24 09:03:51
# 1           100        58     74.37        0.89  2021-04-24 09:04:10
# 2             7        52     67.37        2.06  2021-04-24 09:04:10
# 3            20        73     72.77        2.57  2021-04-24 09:02:11
# 4            20        88     70.97        5.14  2021-04-24 08:59:25
# ..          ...       ...       ...         ...                  ...
# 574          20        66     85.37        2.13  2021-04-24 09:06:20
# 575           0        66     32.85        1.72  2021-04-24 09:06:20
# 576          40        54     83.57        7.72  2021-04-24 09:06:20
# 577          33        85     66.36        1.79  2021-04-24 09:06:21
# 578           0        67     60.17       15.95  2021-04-24 09:06:21
#
# [579 rows x 11 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

vacay=gmaps.figure(map_type='ROADMAP')
locations_df=weather_df[['Lat','Lon']]
humidity=weather_df['Humidity']
heat_layer=gmaps.heatmap_layer(locations_df, weights=humidity,dissipating=False, max_intensity=10, point_radius=1)
vacay.add_layer(heat_layer)
vacay
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#df.loc[(df['column_name'] >= A) & (df['column_name'] <= B)]
Hotel_df=weather_df.loc[(weather_df['Cloudiness']<=25)&
                        (weather_df['Wind Speed']<=15)&
                        ((weather_df['Max Temp']>=65)&(weather_df['Max Temp']<=80))
                       ]
Hotel_df.count()
# Out:
# Unnamed: 0    42
# City ID       42
# City          42
# Country       40
# Lat           42
# Lon           42
# Cloudiness    42
# Humidity      42
# Max Temp      42
# Wind Speed    42
# Date          42
# dtype: int64

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#list for map

hotel_df=pd.DataFrame(columns=['Lat','Lng','Hotel Name','City','Country'])

#parameter dictionary
params={
    "radius":5000,
    "types":"hotel",
    "keyword":"resort",
    "key":g_key
}

for index, row in Hotel_df.iterrows():
    lat=row["Lat"]
    lon=row["Lon"]
    params["location"]=f"{lat},{lon}"
    
    hotel_names=requests.get(base_url,params=params)
    hotel_names=hotel_names.json()
    #print(json.dumps(hotel_names,indent=4,sort_keys=True))
    
    try:
        #if hotel_names["results"][0]["business status"]=="OPERATIONAL":
        hotel_df.loc[index,"Lat"]=hotel_names["results"][0]["geometry"]["location"]["lat"]
        hotel_df.loc[index,"Lng"]=hotel_names["results"][0]["geometry"]["location"]["lng"]
        hotel_df.loc[index,"Hotel Name"]=hotel_names["results"][0]["name"]
        hotel_df.loc[index,"City"]=hotel_names["results"][0]["plus_code"]["compound_code"]
    except (KeyError, IndexError):
            print("Missing field/key error..skipping")
            
#process city and country in dataframe
# Out:
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping
# Missing field/key error..skipping

# %%
print(hotel_df)
hotel_df.to_csv('../output_data/hotel.csv')
# Out:
#           Lat      Lng                                    Hotel Name  \
# 2     -15.774  128.737                 Kununurra Country Club Resort
# 3     21.3395 -158.125          Four Seasons Resort Oahu at Ko Olina
# 23   -33.9086  18.4163                            One&Only Cape Town
# 28   -33.9634  25.6129                      Beza Lodge & Guest House
# 37   -24.8974  113.642                Carnarvon Beach Holiday Resort
# 52  -0.744564 -90.3116                       Hotel Solymar Galapagos
# 78    11.3025 -15.8137                      BOB FISHING CLUB BIJAGOS
# 82   -8.75741 -63.8836                       Hotel Alem Das Estrelas
# 97   -32.9698  27.9673                          P S a Holiday Resort
# 100   5.80404  102.149                                 DMawar Resort
# 106   14.9097 -23.5114                        MLD Cabo Verde Resorts
# 145  -33.6021   26.897                             Port Alfred Sands
# 153     20.94 -17.0346                                   HOTEL TIRIS
# 154   31.6027  34.7643                                    Desert Gat
# 168   22.2866  114.157      PS group_Four Seasons Hotels and Resorts
# 231  -21.6453 -41.0217                                  Resort Lakes
# 238  -4.25111 -81.2317                 Hotel "El Merlin" Cabo Blanco
# 241  -11.0952 -77.6107                    Hotel Vista del Sol Resort
# 254  -22.9694 -42.0313                         Resort Villa da Praia
# 287   39.8552  4.27638                                Mapalu Menorca
# 291   16.8561 -99.8635                   Holiday Inn Resort Acapulco
# 351   13.3191  123.315                             Enon Beach Resort
# 400  -12.3978  16.9401                                iu Hotel Kuíto
# 411  -13.6754 -76.2024                              Huaca Los Cachos
# 418   12.4609   75.696                         Heritage Resort Coorg
# 441   31.2341  29.9458                     SUNRISE Alex Avenue Hotel
# 478  -4.57944 -81.2599                  Complejo Recreacional Certse
# 551  -20.3402 -40.2833  J. P. a Empreendimento Hoteleiro e Turístico
# 553   20.6582 -105.249                   Club Regina Puerto Vallarta
# 557  -20.3107  118.576                           Bruno's Ocean Lodge
# 562  -22.9477  14.5362                              Moonlight Resort
#
#                                                   City Country
# 2      6PGP+9W Kununurra, Western Australia, Australia     NaN
# 3                              8VQF+RR Kapolei, Hawaii     NaN
# 23                     3CR8+GG Cape Town, South Africa     NaN
# 28                      2JP7+J5 Gqeberha, South Africa     NaN
# 37   4J3R+2Q Babbage Island, Western Australia, Aus...     NaN
# 52                       7M4Q+59 Puerto Ayora, Ecuador     NaN
# 78                      853P+2G Bubaque, Guinea-Bissau     NaN
# 82   64V8+2H Embratel, Porto Velho - State of Rondô...     NaN
# 97                   2XJ8+3W East London, South Africa     NaN
# 100            R43X+JQ Tanah Merah, Kelantan, Malaysia     NaN
# 106                          WF5Q+VC Praia, Cape Verde     NaN
# 145                  9VXW+5Q Port Alfred, South Africa     NaN
# 153                     WXR8+24 Nouadhibou, Mauritania     NaN
# 154                         JQ37+3P Kiryat Gat, Israel     NaN
# 168                         75P4+JM Central, Hong Kong     NaN
# 231  9X3H+V8 Atafona, São João da Barra - State of ...     NaN
# 238                              PQX9+H8 El Alto, Peru     NaN
# 241                     W93Q+WP Hualmay District, Peru     NaN
# 254  2XJ9+6F Centro, Arraial do Cabo - State of Rio...     NaN
# 287                          V74G+3H Trebelúger, Spain     NaN
# 291                 V44P+FH Acapulco, Guerrero, Mexico     NaN
# 351           8897+JX Bato, Camarines Sur, Philippines     NaN
# 400                              JW2R+V2 Kuito, Angola     NaN
# 411                                8QFX+R3 Pisco, Peru     NaN
# 418                FM6W+99 Galibeedu, Karnataka, India     NaN
# 441                       6WMW+J8 First Al Raml, Egypt     NaN
# 478                               CPCR+62 Talara, Peru     NaN
# 551  MP58+WM Vila Velha, State of Espírito Santo, B...     NaN
# 553           MQ52+79 Puerto Vallarta, Jalisco, Mexico     NaN
# 557  MHQG+P6 Port Hedland, Western Australia, Austr...     NaN
# 562                        3G2P+WF Swakopmund, Namibia     NaN

# %%
#function to clean the markers - can be imported 
def clean_markers(m_city_list):
    h_locations=[]
    cleaned=[]
    for x in m_city_list:
        clen=(len(x))
        #print(f'original string is {clen}')
        cleaned.append(x[7:clen])
    #print(cleaned)
    for x in cleaned:
        #new=x.split(",",1)
        h_locations.append(x.split(",",1))
    return(h_locations)

markers=[]
markers=clean_markers(hotel_df['City'])
hotel_df[["City","Country"]]=markers
#print(markers[2])
print(hotel_df)
# Out:
#           Lat      Lng                                    Hotel Name  \
# 2     -15.774  128.737                 Kununurra Country Club Resort
# 3     21.3395 -158.125          Four Seasons Resort Oahu at Ko Olina
# 23   -33.9086  18.4163                            One&Only Cape Town
# 28   -33.9634  25.6129                      Beza Lodge & Guest House
# 37   -24.8974  113.642                Carnarvon Beach Holiday Resort
# 52  -0.744564 -90.3116                       Hotel Solymar Galapagos
# 78    11.3025 -15.8137                      BOB FISHING CLUB BIJAGOS
# 82   -8.75741 -63.8836                       Hotel Alem Das Estrelas
# 97   -32.9698  27.9673                          P S a Holiday Resort
# 100   5.80404  102.149                                 DMawar Resort
# 106   14.9097 -23.5114                        MLD Cabo Verde Resorts
# 145  -33.6021   26.897                             Port Alfred Sands
# 153     20.94 -17.0346                                   HOTEL TIRIS
# 154   31.6027  34.7643                                    Desert Gat
# 168   22.2866  114.157      PS group_Four Seasons Hotels and Resorts
# 231  -21.6453 -41.0217                                  Resort Lakes
# 238  -4.25111 -81.2317                 Hotel "El Merlin" Cabo Blanco
# 241  -11.0952 -77.6107                    Hotel Vista del Sol Resort
# 254  -22.9694 -42.0313                         Resort Villa da Praia
# 287   39.8552  4.27638                                Mapalu Menorca
# 291   16.8561 -99.8635                   Holiday Inn Resort Acapulco
# 351   13.3191  123.315                             Enon Beach Resort
# 400  -12.3978  16.9401                                iu Hotel Kuíto
# 411  -13.6754 -76.2024                              Huaca Los Cachos
# 418   12.4609   75.696                         Heritage Resort Coorg
# 441   31.2341  29.9458                     SUNRISE Alex Avenue Hotel
# 478  -4.57944 -81.2599                  Complejo Recreacional Certse
# 551  -20.3402 -40.2833  J. P. a Empreendimento Hoteleiro e Turístico
# 553   20.6582 -105.249                   Club Regina Puerto Vallarta
# 557  -20.3107  118.576                           Bruno's Ocean Lodge
# 562  -22.9477  14.5362                              Moonlight Resort
#
#                   City                                            Country
# 2            Kununurra                       Western Australia, Australia
# 3              Kapolei                                             Hawaii
# 23           Cape Town                                       South Africa
# 28            Gqeberha                                       South Africa
# 37      Babbage Island                       Western Australia, Australia
# 52        Puerto Ayora                                            Ecuador
# 78             Bubaque                                      Guinea-Bissau
# 82            Embratel            Porto Velho - State of Rondônia, Brazil
# 97         East London                                       South Africa
# 100        Tanah Merah                                 Kelantan, Malaysia
# 106              Praia                                         Cape Verde
# 145        Port Alfred                                       South Africa
# 153         Nouadhibou                                         Mauritania
# 154         Kiryat Gat                                             Israel
# 168            Central                                          Hong Kong
# 231            Atafona   São João da Barra - State of Rio de Janeiro, ...
# 238            El Alto                                               Peru
# 241   Hualmay District                                               Peru
# 254             Centro   Arraial do Cabo - State of Rio de Janeiro, Br...
# 287         Trebelúger                                              Spain
# 291           Acapulco                                   Guerrero, Mexico
# 351               Bato                         Camarines Sur, Philippines
# 400              Kuito                                             Angola
# 411              Pisco                                               Peru
# 418          Galibeedu                                   Karnataka, India
# 441      First Al Raml                                              Egypt
# 478             Talara                                               Peru
# 551         Vila Velha                    State of Espírito Santo, Brazil
# 553    Puerto Vallarta                                    Jalisco, Mexico
# 557       Port Hedland                       Western Australia, Australia
# 562         Swakopmund                                            Namibia

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
print(hotel_info)
h_locations = hotel_df[["Lat", "Lng"]]
print(h_locations)
# Out:
# ['\n<dl>\n<dt>Name</dt><dd>Kununurra Country Club Resort</dd>\n<dt>City</dt><dd> Kununurra</dd>\n<dt>Country</dt><dd> Western Australia, Australia</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Four Seasons Resort Oahu at Ko Olina</dd>\n<dt>City</dt><dd> Kapolei</dd>\n<dt>Country</dt><dd> Hawaii</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>One&Only Cape Town</dd>\n<dt>City</dt><dd> Cape Town</dd>\n<dt>Country</dt><dd> South Africa</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Beza Lodge & Guest House</dd>\n<dt>City</dt><dd> Gqeberha</dd>\n<dt>Country</dt><dd> South Africa</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Carnarvon Beach Holiday Resort</dd>\n<dt>City</dt><dd> Babbage Island</dd>\n<dt>Country</dt><dd> Western Australia, Australia</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Solymar Galapagos</dd>\n<dt>City</dt><dd> Puerto Ayora</dd>\n<dt>Country</dt><dd> Ecuador</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>BOB FISHING CLUB BIJAGOS</dd>\n<dt>City</dt><dd> Bubaque</dd>\n<dt>Country</dt><dd> Guinea-Bissau</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Alem Das Estrelas</dd>\n<dt>City</dt><dd> Embratel</dd>\n<dt>Country</dt><dd> Porto Velho - State of Rondônia, Brazil</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>P S a Holiday Resort</dd>\n<dt>City</dt><dd> East London</dd>\n<dt>Country</dt><dd> South Africa</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>DMawar Resort</dd>\n<dt>City</dt><dd> Tanah Merah</dd>\n<dt>Country</dt><dd> Kelantan, Malaysia</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>MLD Cabo Verde Resorts</dd>\n<dt>City</dt><dd> Praia</dd>\n<dt>Country</dt><dd> Cape Verde</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Port Alfred Sands</dd>\n<dt>City</dt><dd> Port Alfred</dd>\n<dt>Country</dt><dd> South Africa</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>HOTEL TIRIS</dd>\n<dt>City</dt><dd> Nouadhibou</dd>\n<dt>Country</dt><dd> Mauritania</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Desert Gat</dd>\n<dt>City</dt><dd> Kiryat Gat</dd>\n<dt>Country</dt><dd> Israel</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>PS group_Four Seasons Hotels and Resorts</dd>\n<dt>City</dt><dd> Central</dd>\n<dt>Country</dt><dd> Hong Kong</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Resort Lakes</dd>\n<dt>City</dt><dd> Atafona</dd>\n<dt>Country</dt><dd> São João da Barra - State of Rio de Janeiro, Brazil</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel "El Merlin" Cabo Blanco</dd>\n<dt>City</dt><dd> El Alto</dd>\n<dt>Country</dt><dd> Peru</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Vista del Sol Resort</dd>\n<dt>City</dt><dd> Hualmay District</dd>\n<dt>Country</dt><dd> Peru</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Resort Villa da Praia</dd>\n<dt>City</dt><dd> Centro</dd>\n<dt>Country</dt><dd> Arraial do Cabo - State of Rio de Janeiro, Brazil</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Mapalu Menorca</dd>\n<dt>City</dt><dd> Trebelúger</dd>\n<dt>Country</dt><dd> Spain</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Holiday Inn Resort Acapulco</dd>\n<dt>City</dt><dd> Acapulco</dd>\n<dt>Country</dt><dd> Guerrero, Mexico</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Enon Beach Resort</dd>\n<dt>City</dt><dd> Bato</dd>\n<dt>Country</dt><dd> Camarines Sur, Philippines</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>iu Hotel Kuíto</dd>\n<dt>City</dt><dd> Kuito</dd>\n<dt>Country</dt><dd> Angola</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Huaca Los Cachos</dd>\n<dt>City</dt><dd> Pisco</dd>\n<dt>Country</dt><dd> Peru</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Heritage Resort Coorg</dd>\n<dt>City</dt><dd> Galibeedu</dd>\n<dt>Country</dt><dd> Karnataka, India</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>SUNRISE Alex Avenue Hotel</dd>\n<dt>City</dt><dd> First Al Raml</dd>\n<dt>Country</dt><dd> Egypt</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Complejo Recreacional Certse</dd>\n<dt>City</dt><dd> Talara</dd>\n<dt>Country</dt><dd> Peru</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>J. P. a Empreendimento Hoteleiro e Turístico</dd>\n<dt>City</dt><dd> Vila Velha</dd>\n<dt>Country</dt><dd> State of Espírito Santo, Brazil</dd>\ ...
#           Lat      Lng
# 2     -15.774  128.737
# 3     21.3395 -158.125
# 23   -33.9086  18.4163
# 28   -33.9634  25.6129
# 37   -24.8974  113.642
# 52  -0.744564 -90.3116
# 78    11.3025 -15.8137
# 82   -8.75741 -63.8836
# 97   -32.9698  27.9673
# 100   5.80404  102.149
# 106   14.9097 -23.5114
# 145  -33.6021   26.897
# 153     20.94 -17.0346
# 154   31.6027  34.7643
# 168   22.2866  114.157
# 231  -21.6453 -41.0217
# 238  -4.25111 -81.2317
# 241  -11.0952 -77.6107
# 254  -22.9694 -42.0313
# 287   39.8552  4.27638
# 291   16.8561 -99.8635
# 351   13.3191  123.315
# 400  -12.3978  16.9401
# 411  -13.6754 -76.2024
# 418   12.4609   75.696
# 441   31.2341  29.9458
# 478  -4.57944 -81.2599
# 551  -20.3402 -40.2833
# 553   20.6582 -105.249
# 557  -20.3107  118.576
# 562  -22.9477  14.5362

# %%
# Add marker layer ontop of heat map
gmaps.configure(api_key=g_key)

Hotels=gmaps.figure()
locations_df=weather_df[['Lat','Lon']]
humidity=weather_df['Humidity']
heat_layer=gmaps.heatmap_layer(locations_df, weights=humidity,dissipating=False, max_intensity=10, point_radius=1)
marker_layer=gmaps.marker_layer(h_locations,info_box_content=hotel_info)
Hotels.add_layer(heat_layer)
Hotels.add_layer(marker_layer)
Hotels

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Update sklearn to prevent version mismatches
#!pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
#!pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
selected_features = df.drop("koi_disposition", axis=1)

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df["koi_disposition"]
print(selected_features.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
y.unique()
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
X_train, X_test, y_train, y_test = train_test_split(selected_features, y, random_state=1)
X_train.head()
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3563     5.470000e-05    -5.470000e-05   139.064020          0.004110
# 4099     1.365000e-04    -1.365000e-04   140.207320          0.004460
# 5460     1.230000e-07    -1.230000e-07   131.792007          0.000096
# 1091     1.461000e-03    -1.461000e-03   187.569860          0.005290
# 5999     3.181000e-03    -3.181000e-03   175.715600          0.028600
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 3563         -0.004110  ...            -133      4.387           0.066
# 4099         -0.004460  ...            -144      4.519           0.078
# 5460         -0.000096  ...            -140      4.594           0.054
# 1091         -0.005290  ...            -112      4.447           0.072
# 5999         -0.028600  ...            -233      4.145           0.164
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 3563          -0.123     1.092          0.181         -0.097  298.09543
# 4099          -0.052     0.804          0.056         -0.076  295.73535
# 5460          -0.027     0.683          0.054         -0.060  292.18417
# 1091          -0.108     0.954          0.135         -0.083  283.11377
# 5999          -0.164     1.608          0.905         -0.383  294.93198
#
#             dec  koi_kepmag
# 3563  44.737061      13.204
# 4099  42.576248      15.514
# 5460  49.310040      15.414
# 1091  48.131390      13.328
# 5999  39.812420      12.964
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create model and add layers
model = Sequential()
model.add(Dense(units=50, activation='relu', input_dim=40))
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# model.summary()

model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.7183 - accuracy: 0.6601
# Epoch 2/100
# 164/164 - 0s - loss: 0.3981 - accuracy: 0.8064
# Epoch 3/100
# 164/164 - 0s - loss: 0.3720 - accuracy: 0.8117
# Epoch 4/100
# 164/164 - 0s - loss: 0.3596 - accuracy: 0.8236
# Epoch 5/100
# 164/164 - 0s - loss: 0.3533 - accuracy: 0.8268
# Epoch 6/100
# 164/164 - 0s - loss: 0.3428 - accuracy: 0.8352
# Epoch 7/100
# 164/164 - 0s - loss: 0.3430 - accuracy: 0.8375
# Epoch 8/100
# 164/164 - 0s - loss: 0.3353 - accuracy: 0.8390
# Epoch 9/100
# 164/164 - 0s - loss: 0.3336 - accuracy: 0.8367
# Epoch 10/100
# 164/164 - 0s - loss: 0.3247 - accuracy: 0.8467
# Epoch 11/100
# 164/164 - 0s - loss: 0.3213 - accuracy: 0.8518
# Epoch 12/100
# 164/164 - 0s - loss: 0.3216 - accuracy: 0.8518
# Epoch 13/100
# 164/164 - 0s - loss: 0.3140 - accuracy: 0.8547
# Epoch 14/100
# 164/164 - 0s - loss: 0.3145 - accuracy: 0.8604
# Epoch 15/100
# 164/164 - 0s - loss: 0.3075 - accuracy: 0.8617
# Epoch 16/100
# 164/164 - 0s - loss: 0.3085 - accuracy: 0.8600
# Epoch 17/100
# 164/164 - 0s - loss: 0.3034 - accuracy: 0.8667
# Epoch 18/100
# 164/164 - 0s - loss: 0.3020 - accuracy: 0.8655
# Epoch 19/100
# 164/164 - 0s - loss: 0.3002 - accuracy: 0.8669
# Epoch 20/100
# 164/164 - 0s - loss: 0.2984 - accuracy: 0.8657
# Epoch 21/100
# 164/164 - 0s - loss: 0.2971 - accuracy: 0.8640
# Epoch 22/100
# 164/164 - 0s - loss: 0.2941 - accuracy: 0.8695
# Epoch 23/100
# 164/164 - 0s - loss: 0.2934 - accuracy: 0.8703
# Epoch 24/100
# 164/164 - 0s - loss: 0.2971 - accuracy: 0.8653
# Epoch 25/100
# 164/164 - 0s - loss: 0.2897 - accuracy: 0.8747
# Epoch 26/100
# 164/164 - 0s - loss: 0.2867 - accuracy: 0.8774
# Epoch 27/100
# 164/164 - 0s - loss: 0.2867 - accuracy: 0.8766
# Epoch 28/100
# 164/164 - 0s - loss: 0.2856 - accuracy: 0.8747
# Epoch 29/100
# 164/164 - 0s - loss: 0.2870 - accuracy: 0.8772
# Epoch 30/100
# 164/164 - 0s - loss: 0.2853 - accuracy: 0.8772
# Epoch 31/100
# 164/164 - 0s - loss: 0.2817 - accuracy: 0.8789
# Epoch 32/100
# 164/164 - 0s - loss: 0.2829 - accuracy: 0.8804
# Epoch 33/100
# 164/164 - 0s - loss: 0.2840 - accuracy: 0.8756
# Epoch 34/100
# 164/164 - 0s - loss: 0.2810 - accuracy: 0.8816
# Epoch 35/100
# 164/164 - 0s - loss: 0.2783 - accuracy: 0.8783
# Epoch 36/100
# 164/164 - 0s - loss: 0.2780 - accuracy: 0.8819
# Epoch 37/100
# 164/164 - 0s - loss: 0.2825 - accuracy: 0.8762
# Epoch 38/100
# 164/164 - 0s - loss: 0.2810 - accuracy: 0.8756
# Epoch 39/100
# 164/164 - 0s - loss: 0.2769 - accuracy: 0.8804
# Epoch 40/100
# 164/164 - 0s - loss: 0.2758 - accuracy: 0.8766
# Epoch 41/100
# 164/164 - 0s - loss: 0.2747 - accuracy: 0.8800
# Epoch 42/100
# 164/164 - 0s - loss: 0.2774 - accuracy: 0.8779
# Epoch 43/100
# 164/164 - 0s - loss: 0.2786 - accuracy: 0.8804
# Epoch 44/100
# 164/164 - 0s - loss: 0.2709 - accuracy: 0.8817
# Epoch 45/100
# 164/164 - 0s - loss: 0.2799 - accuracy: 0.8747
# Epoch 46/100
# 164/164 - 0s - loss: 0.2707 - accuracy: 0.8821
# Epoch 47/100
# 164/164 - 0s - loss: 0.2721 - accuracy: 0.8806
# Epoch 48/100
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8863
# Epoch 49/100
# 164/164 - 0s - loss: 0.2770 - accuracy: 0.8796
# Epoch 50/100
# 164/164 - 0s - loss: 0.2655 - accuracy: 0.8861
# Epoch 51/100
# 164/164 - 0s - loss: 0.2733 - accuracy: 0.8804
# Epoch 52/100
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8827
# Epoch 53/100
# 164/164 - 0s - loss: 0.2661 - accuracy: 0.8865
# Epoch 54/100
# 164/164 - 0s - loss: 0.2674 - accuracy: 0.8863
# Epoch 55/100
# 164/164 - 0s - loss: 0.2669 - accuracy: 0.8879
# Epoch 56/100
# 164/164 - 0s - loss: 0.2684 - accuracy: 0.8846
# Epoch 57/100
# 164/164 - 0s - loss: 0.2679 - accuracy: 0.8829
# Epoch 58/100
# 164/164 - 0s - loss: 0.2618 - accuracy: 0.8865
# Epoch 59/100
# 164/164 - 0s - loss: 0.2644 - accuracy: 0.8877
# Epoch 60/100
# 164/164 - 0s - loss: 0.2600 - accuracy: 0.8859
# Epoch 61/100
# 164/164 - 0s - loss: 0.2649 - accuracy: 0.8854
# Epoch 62/100
# 164/164 - 0s - loss: 0.2572 - accuracy: 0.8915
# Epoch 63/100
# 164/164 - 0s - loss: 0.2596 - accuracy: 0.8879
# Epoch 64/100
# 164/164 - 0s - loss: 0.2659 - accuracy: 0.8837
# Epoch 65/100
# 164/164 - 0s - loss: 0.2624 - accuracy: 0.8861
# Epoch 66/100
# 164/164 - 0s - loss: 0.2561 - accuracy: 0.8873
# Epoch 67/100
# 164/164 - 0s - loss: 0.2577 - accuracy: 0.8873
# Epoch 68/100
# 164/164 - 0s - loss: 0.2548 - accuracy: 0.8896
# Epoch 69/100
# 164/164 - 0s - loss: 0.2555 - accuracy: 0.8882
# Epoch 70/100
# 164/164 - 0s - loss: 0.2561 - accuracy: 0.8867
# Epoch 71/100
# 164/164 - 0s - loss: 0.2500 - accuracy: 0.8957
# Epoch 72/100
# 164/164 - 0s - loss: 0.2530 - accuracy: 0.8886
# Epoch 73/100
# 164/164 - 0s - loss: 0.2549 - accuracy: 0.8858
# Epoch 74/100
# 164/164 - 0s - loss: 0.2521 - accuracy: 0.8903
# Epoch 75/100
# 164/164 - 0s - loss: 0.2615 - accuracy: 0.8859
# Epoch 76/100
# 164/164 - 0s - loss: 0.2551 - accuracy: 0.8863
# Epoch 77/100
# 164/164 - 0s - loss: 0.2498 - accuracy: 0.8917
# Epoch 78/100
# 164/164 - 0s - loss: 0.2509 - accuracy: 0.8879
# Epoch 79/100
# 164/164 - 0s - loss: 0.2486 - accuracy: 0.8934
# Epoch 80/100
# 164/164 - 0s - loss: 0.2503 - accuracy: 0.8922
# Epoch 81/100
# 164/164 - 0s - loss: 0.2531 - accuracy: 0.8875
# Epoch 82/100
# 164/164 - 0s - loss: 0.2497 - accuracy: 0.8877
# Epoch 83/100
# 164/164 - 0s - loss: 0.2530 - accuracy: 0.8899
# Epoch 84/100
# 164/164 - 0s - loss: 0.2469 - accuracy: 0.8898
# Epoch 85/100
# 164/164 - 0s - loss: 0.2476 - accuracy: 0.8913
# Epoch 86/100
# 164/164 - 0s - loss: 0.2531 - accuracy: 0.8899
# Epoch 87/100
# 164/164 - 0s - loss: 0.2490 - accuracy: 0.8922
# Epoch 88/100
# 164/164 - 0s - loss: 0.2462 - accuracy: 0.8924
# Epoch 89/100
# 164/164 - 0s - loss: 0.2493 - accuracy: 0.8922
# Epoch 90/100
# 164/164 - 0s - loss: 0.2525 - accuracy: 0.8890
# Epoch 91/100
# 164/164 - 0s - loss: 0.2431 - accuracy: 0.8953
# Epoch 92/100
# 164/164 - 0s - loss: 0.2423 - accuracy: 0.8928
# Epoch 93/100
# 164/164 - 0s - loss: 0.2442 - accuracy: 0.8930
# Epoch 94/100
# 164/164 - 0s - loss: 0.2367 - accuracy: 0.8981
# Epoch 95/100
# 164/164 - 0s - loss: 0.2398 - accuracy: 0.8966
# Epoch 96/100
# 164/164 - 0s - loss: 0.2468 - accuracy: 0.8884
# Epoch 97/100
# 164/164 - 0s - loss: 0.2419 - accuracy: 0.8917
# Epoch 98/100
# 164/164 - 0s - loss: 0.2383 - accuracy: 0.8964
# Epoch 99/100
# 164/164 - 0s - loss: 0.2434 - accuracy: 0.8928
# Epoch 100/100
# 164/164 - 0s - loss: 0.2411 - accuracy: 0.8938

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2945 - accuracy: 0.8713
# Normal Neural Network - Loss: 0.29445910453796387, Accuracy: 0.8712814450263977

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE']

# %%
import numpy as np
encoded_predictions = np.argmax(model.predict(X_test_scaled), axis=1)     
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' ... 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CANDIDATE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE']

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'DL.h5'
model.save(filename)

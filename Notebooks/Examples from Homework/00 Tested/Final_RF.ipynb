# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set target, features and feature_names.
target = df["koi_disposition"]
data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_minmax = X_minmax.transform(X_train)
X_test_minmax = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train_minmax, y_train)
# Out:
# RandomForestClassifier()

# %%
print(f"Training Data Score: {rf.score(X_train_minmax, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_minmax, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8998855835240275

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10397884733057768, 'koi_fpflag_co'),
#  (0.09840229833582813, 'koi_fpflag_nt'),
#  (0.06713954374099619, 'koi_fpflag_ss'),
#  (0.0533875326674477, 'koi_model_snr'),
#  (0.05144221944113528, 'koi_prad'),
#  (0.037816260262782404, 'koi_duration_err2'),
#  (0.03549195179442181, 'koi_fpflag_ec'),
#  (0.033245574891184126, 'koi_steff_err1'),
#  (0.032752270334791715, 'koi_prad_err1'),
#  (0.032721564079781426, 'koi_duration_err1'),
#  (0.02857446175004299, 'koi_steff_err2'),
#  (0.02427836787145574, 'koi_period'),
#  (0.02349033253670444, 'koi_time0bk_err2'),
#  (0.023273228977157532, 'koi_depth'),
#  (0.02315722182423762, 'koi_prad_err2'),
#  (0.022804221869727487, 'koi_time0bk_err1'),
#  (0.02166561974957854, 'koi_duration'),
#  (0.02165873376185435, 'koi_period_err2'),
#  (0.01957244619497552, 'koi_impact'),
#  (0.017198161430029803, 'koi_teq'),
#  (0.01646112753821424, 'koi_period_err1'),
#  (0.016379653948650288, 'koi_insol_err1'),
#  (0.015388859520933294, 'koi_insol_err2'),
#  (0.01418636681569043, 'koi_depth_err1'),
#  (0.013699621272448332, 'koi_insol'),
#  (0.012888708424336377, 'koi_time0bk'),
#  (0.01280986541632083, 'koi_depth_err2'),
#  (0.012169679501217959, 'ra'),
#  (0.011385232919183245, 'koi_srad_err1'),
#  (0.011197299933762868, 'dec'),
#  (0.010909418222751441, 'koi_kepmag'),
#  (0.010837433069296477, 'koi_impact_err1'),
#  (0.010733129320895932, 'koi_impact_err2'),
#  (0.010415278542020763, 'koi_slogg_err2'),
#  (0.009775862820342693, 'koi_slogg'),
#  (0.009727087741939797, 'koi_steff'),
#  (0.009252442194670807, 'koi_srad'),
#  (0.009060705205454581, 'koi_slogg_err1'),
#  (0.007947930458500313, 'koi_srad_err2'),
#  (0.0027234382886587517, 'koi_tce_plnt_num')]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [250, 300, 350, 400],
              'max_depth': [125, 150, 175, 200]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_minmax, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ...max_depth=125, n_estimators=250;, score=0.903 total time=   2.9s
# [CV 2/5] END ...max_depth=125, n_estimators=250;, score=0.901 total time=   2.8s
# [CV 3/5] END ...max_depth=125, n_estimators=250;, score=0.884 total time=   2.9s
# [CV 4/5] END ...max_depth=125, n_estimators=250;, score=0.885 total time=   2.8s
# [CV 5/5] END ...max_depth=125, n_estimators=250;, score=0.881 total time=   2.9s
# [CV 1/5] END ...max_depth=125, n_estimators=300;, score=0.907 total time=   3.5s
# [CV 2/5] END ...max_depth=125, n_estimators=300;, score=0.905 total time=   3.4s
# [CV 3/5] END ...max_depth=125, n_estimators=300;, score=0.885 total time=   3.5s
# [CV 4/5] END ...max_depth=125, n_estimators=300;, score=0.884 total time=   3.4s
# [CV 5/5] END ...max_depth=125, n_estimators=300;, score=0.883 total time=   3.5s
# [CV 1/5] END ...max_depth=125, n_estimators=350;, score=0.905 total time=   4.1s
# [CV 2/5] END ...max_depth=125, n_estimators=350;, score=0.902 total time=   4.0s
# [CV 3/5] END ...max_depth=125, n_estimators=350;, score=0.883 total time=   4.0s
# [CV 4/5] END ...max_depth=125, n_estimators=350;, score=0.880 total time=   4.0s
# [CV 5/5] END ...max_depth=125, n_estimators=350;, score=0.884 total time=   4.0s
# [CV 1/5] END ...max_depth=125, n_estimators=400;, score=0.904 total time=   4.7s
# [CV 2/5] END ...max_depth=125, n_estimators=400;, score=0.908 total time=   4.5s
# [CV 3/5] END ...max_depth=125, n_estimators=400;, score=0.886 total time=   4.7s
# [CV 4/5] END ...max_depth=125, n_estimators=400;, score=0.884 total time=   4.6s
# [CV 5/5] END ...max_depth=125, n_estimators=400;, score=0.883 total time=   4.7s
# [CV 1/5] END ...max_depth=150, n_estimators=250;, score=0.904 total time=   2.8s
# [CV 2/5] END ...max_depth=150, n_estimators=250;, score=0.905 total time=   2.8s
# [CV 3/5] END ...max_depth=150, n_estimators=250;, score=0.885 total time=   2.9s
# [CV 4/5] END ...max_depth=150, n_estimators=250;, score=0.881 total time=   2.8s
# [CV 5/5] END ...max_depth=150, n_estimators=250;, score=0.883 total time=   2.8s
# [CV 1/5] END ...max_depth=150, n_estimators=300;, score=0.905 total time=   3.5s
# [CV 2/5] END ...max_depth=150, n_estimators=300;, score=0.901 total time=   3.4s
# [CV 3/5] END ...max_depth=150, n_estimators=300;, score=0.885 total time=   3.5s
# [CV 4/5] END ...max_depth=150, n_estimators=300;, score=0.885 total time=   3.4s
# [CV 5/5] END ...max_depth=150, n_estimators=300;, score=0.883 total time=   3.4s
# [CV 1/5] END ...max_depth=150, n_estimators=350;, score=0.903 total time=   4.0s
# [CV 2/5] END ...max_depth=150, n_estimators=350;, score=0.904 total time=   4.0s
# [CV 3/5] END ...max_depth=150, n_estimators=350;, score=0.882 total time=   4.0s
# [CV 4/5] END ...max_depth=150, n_estimators=350;, score=0.885 total time=   4.0s
# [CV 5/5] END ...max_depth=150, n_estimators=350;, score=0.884 total time=   4.1s
# [CV 1/5] END ...max_depth=150, n_estimators=400;, score=0.906 total time=   4.6s
# [CV 2/5] END ...max_depth=150, n_estimators=400;, score=0.904 total time=   4.6s
# [CV 3/5] END ...max_depth=150, n_estimators=400;, score=0.885 total time=   4.7s
# [CV 4/5] END ...max_depth=150, n_estimators=400;, score=0.885 total time=   4.6s
# [CV 5/5] END ...max_depth=150, n_estimators=400;, score=0.884 total time=   4.6s
# [CV 1/5] END ...max_depth=175, n_estimators=250;, score=0.901 total time=   2.9s
# [CV 2/5] END ...max_depth=175, n_estimators=250;, score=0.906 total time=   2.8s
# [CV 3/5] END ...max_depth=175, n_estimators=250;, score=0.887 total time=   3.0s
# [CV 4/5] END ...max_depth=175, n_estimators=250;, score=0.881 total time=   2.8s
# [CV 5/5] END ...max_depth=175, n_estimators=250;, score=0.877 total time=   2.9s
# [CV 1/5] END ...max_depth=175, n_estimators=300;, score=0.900 total time=   3.5s
# [CV 2/5] END ...max_depth=175, n_estimators=300;, score=0.909 total time=   3.4s
# [CV 3/5] END ...max_depth=175, n_estimators=300;, score=0.892 total time=   3.4s
# [CV 4/5] END ...max_depth=175, n_estimators=300;, score=0.883 total time=   3.4s
# [CV 5/5] END ...max_depth=175, n_estimators=300;, score=0.886 total time=   3.4s
# [CV 1/5] END ...max_depth=175, n_estimators=350;, score=0.907 total time=   4.1s
# [CV 2/5] END ...max_depth=175, n_estimators=350;, score=0.905 total time=   4.0s
# [CV 3/5] END ...max_depth=175, n_estimators=350;, score=0.882 total time=   4.0s
# [CV 4/5] END ...max_depth=175, n_estimators=350;, score=0.883 total time=   4.0s
# [CV 5/5] END ...max_depth=175, n_estimators=350;, score=0.883 total time=   4.1s
# [CV 1/5] END ...max_depth=175, n_estimators=400;, score=0.900 total time=   4.7s
# [CV 2/5] END ...max_depth=175, n_estimators=400;, score=0.906 total time=   4.6s
# [CV 3/5] END ...max_depth=175, n_estimators=400;, score=0.885 total time=   4.7s
# [CV 4/5] END ...max_depth=175, n_estimators=400;, score=0.885 total time=   4.6s
# [CV 5/5] END ...max_depth=175, n_estimators=400;, score=0.886 total time=   4.7s
# [CV 1/5] END ...max_depth=200, n_estimators=250;, score=0.903 total time=   2.9s
# [CV 2/5] END ...max_depth=200, n_estimators=250;, score=0.908 total time=   2.8s
# [CV 3/5] END ...max_depth=200, n_estimators=250;, score=0.888 total time=   2.9s
# [CV 4/5] END ...max_depth=200, n_estimators=250;, score=0.883 total time=   2.9s
# [CV 5/5] END ...max_depth=200, n_estimators=250;, score=0.883 total time=   2.8s
# [CV 1/5] END ...max_depth=200, n_estimators=300;, score=0.900 total time=   3.5s
# [CV 2/5] END ...max_depth=200, n_estimators=300;, score=0.903 total time=   3.4s
# [CV 3/5] END ...max_depth=200, n_estimators=300;, score=0.884 total time=   3.5s
# [CV 4/5] END ...max_depth=200, n_estimators=300;, score=0.882 total time=   3.4s
# [CV 5/5] END ...max_depth=200, n_estimators=300;, score=0.886 total time=   3.5s
# [CV 1/5] END ...max_depth=200, n_estimators=350;, score=0.905 total time=   4.1s
# [CV 2/5] END ...max_depth=200, n_estimators=350;, score=0.899 total time=   3.9s
# [CV 3/5] END ...max_depth=200, n_estimators=350;, score=0.884 total time=   4.0s
# [CV 4/5] END ...max_depth=200, n_estimators=350;, score=0.882 total time=   4.0s
# [CV 5/5] END ...max_depth=200, n_estimators=350;, score=0.883 total time=   4.1s
# [CV 1/5] END ...max_depth=200, n_estimators=400;, score=0.904 total time=   4.7s
# [CV 2/5] END ...max_depth=200, n_estimators=400;, score=0.903 total time=   4.6s
# [CV 3/5] END ...max_depth=200, n_estimators=400;, score=0.886 total time=   4.6s
# [CV 4/5] END ...max_depth=200, n_estimators=400;, score=0.880 total time=   4.6s
# [CV 5/5] END ...max_depth=200, n_estimators=400;, score=0.882 total time=   4.7s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [125, 150, 175, 200],
#                          'n_estimators': [250, 300, 350, 400]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 175, 'n_estimators': 250}
# 0.8928052161637037

# %%
# Training score:
grid.score(X_train_minmax, y_train)
# Out:
# 1.0

# %%
# Testing score:
grid.score(X_test_minmax, y_test)
# Out:
# 0.8998855835240275

# %%
# Make prediction and save to variable for report.
predictions = grid.predict(X_test_minmax)

# %%
# Print Classification Report.
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.83      0.76      0.79       411
#      CONFIRMED       0.84      0.85      0.84       484
# FALSE POSITIVE       0.97      1.00      0.98       853
#
#       accuracy                           0.90      1748
#      macro avg       0.88      0.87      0.87      1748
#   weighted avg       0.90      0.90      0.90      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'FinalRF_1.sav'
joblib.dump(rf, filename)
# Out:
# ['FinalRF_1.sav']

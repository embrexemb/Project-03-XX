# %%
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #files
# Cheyenne_N = "2016-Cheyenne-NO2.csv"
# ElPaso_N = "2016-ElPaso-NO2.csv"
# LA_N = "2016-LA-NO2.csv"
# NY_N = "2016-NY-NO2.csv"
# Raleigh_N = "2016-Raleigh-NO2.csv"
# Seattle_N = "2016-Seattle-NO2.csv"
#
# ch_csv="CH2016.csv"
# ep_csv="EP2016.csv"
# la_csv="LA2016.csv"
# ny_csv="Y2016.csv"
# ra_csv="RA2016.csv"
# se_csv="SE2016.csv"

# %% [markdown]
# #files
# Cheyenne_N = "2018-Cheyenne-NO2.csv"
# ElPaso_N = "2018-ElPaso-NO2.csv"
# LA_N = "2018-LA-NO2.csv"
# NY_N = "2018-NY-NO2.csv"
# Raleigh_N = "2018-Raleigh-NO2.csv"
# Seattle_N = "2018-Seattle-NO2.csv"
#
# ch_csv="CH2018.csv"
# ep_csv="EP2018.csv"
# la_csv="LA2018.csv"
# ny_csv="Y2018.csv"
# ra_csv="RA2018.csv"
# se_csv="SE2018.csv"

# %%
Cheyenne_N = "2020-Cheyenne-NO2.csv"
ElPaso_N = "2020-ElPaso-NO2.csv"
LA_N = "2020-LA-NO2.csv"
NY_N = "2020-NY-NO2.csv"
Raleigh_N = "2020-Raleigh-NO2.csv"
Seattle_N = "2020-Seattle-NO2.csv"

ch_csv="CH2020.csv"
ep_csv="EP2020.csv"
la_csv="LA2020.csv"
ny_csv="Y2020.csv"
ra_csv="RA2020.csv"
se_csv="SE2020.csv"

# %%
#Read into Pandas Dataframe
df_CH = pd.read_csv(Cheyenne_N)
df_EP = pd.read_csv(ElPaso_N)
df_LA = pd.read_csv(LA_N)
df_NY = pd.read_csv(NY_N)
df_RA = pd.read_csv(Raleigh_N)
df_SE = pd.read_csv(Seattle_N)

# %%
df_CH.dropna()
df_CH.head()
# Out:
#        Date Source    Site ID  POC  Daily Max 1-hour NO2 Concentration UNITS  \
# 0  1/1/2020    AQS  560210003    1                                 1.8   ppb
# 1  1/2/2020    AQS  560210003    1                                 3.7   ppb
# 2  1/3/2020    AQS  560210003    1                                 4.7   ppb
# 3  1/4/2020    AQS  560210003    1                                 4.2   ppb
# 4  1/5/2020    AQS  560210003    1                                 2.0   ppb
#
#    DAILY_AQI_VALUE              Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0                1  Laramie County Mobile               24               100
# 1                3  Laramie County Mobile               23                96
# 2                4  Laramie County Mobile               23                96
# 3                4  Laramie County Mobile               23                96
# 4                2  Laramie County Mobile               24               100
#
# ...

# %%
df_CH=df_CH[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 1-hour NO2 Concentration','DAILY_AQI_VALUE']]
df_CH.to_csv(ch_csv)

# %%
df_SE=df_SE[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 1-hour NO2 Concentration','DAILY_AQI_VALUE']]
df_EP=df_EP[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 1-hour NO2 Concentration','DAILY_AQI_VALUE']]
df_LA=df_LA[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 1-hour NO2 Concentration','DAILY_AQI_VALUE']]
df_NY=df_NY[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 1-hour NO2 Concentration','DAILY_AQI_VALUE']]
df_RA=df_RA[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 1-hour NO2 Concentration','DAILY_AQI_VALUE']]

# %%
#df_CH['Site Name'].unique()

# %%
df_SE.dropna()
df_SE['Site Name'].unique()
df_SE.to_csv(se_csv)

# %%
df_EP.dropna()
df_EP['Site Name'].unique()
df_EP.to_csv(ep_csv)

# %%
df_LA.dropna()
df_LA['Site Name'].unique()
df_LA.to_csv(la_csv)

# %%
df_NY.dropna()
df_NY['Site Name'].unique()

df_NY.to_csv(ny_csv ,encoding='ISO-8859-1')

# %%
df_RA.dropna()
df_RA['Site Name'].unique()
df_RA.to_csv(ra_csv)

# %%
#files are cleaned - merge manually

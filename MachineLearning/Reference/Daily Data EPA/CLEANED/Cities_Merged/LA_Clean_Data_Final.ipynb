# %%
import pandas as pd
import io
from io import StringIO

# %% [markdown]
# READ THE CSV AND PERFORM BASIC DATA CLEANING

# %%
df_01 = pd.read_csv("UrbanGroup/LA/LA2016DF.csv")
#print(df_01.count())
print(df_01)
#drop the null rows
df_01 = df_01.dropna()
print(df_01.count())
print(df_01['Site Name'].unique())
# Out:
#       Unnamed: 0          Site Name        Date  DMean PM10 PM10 Units  \
# 0              0              Azusa    1/1/2016        12.0   ug/m3 SC
# 1              1              Azusa    1/7/2016         7.0   ug/m3 SC
# 2              2              Azusa   1/13/2016        32.0   ug/m3 SC
# 3              3              Azusa   1/19/2016        24.0   ug/m3 SC
# 4              4              Azusa   1/25/2016        16.0   ug/m3 SC
# ...          ...                ...         ...         ...        ...
# 7242        7242  Anaheim Near-Road   4/13/2016         NaN        NaN
# 7243        7243  Anaheim Near-Road   4/14/2016         NaN        NaN
# 7244        7244      Mission Viejo   2/19/2016         NaN        NaN
# 7245        7245      Mission Viejo   8/30/2016         NaN        NaN
# 7246        7246      Mission Viejo  12/31/2016         NaN        NaN
#
#       PM10 AQI      Lat        Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone  \
# 0         11.0  34.1365 -117.92391      14.5       ppb     13.0       0.043
# 1          6.0  34.1365 -117.92391      24.9       ppb     23.0       0.035
# 2         30.0  34.1365 -117.92391      47.4       ppb     44.0       0.013
# 3         22.0  34.1365 -117.92391      25.9       ppb     24.0       0.015
# 4         15.0  34.1365 -117.92391      21.8       ppb     20.0       0.036
# ...        ...      ...        ...       ...       ...      ...         ...
# 7242       NaN      NaN        NaN       NaN       NaN      NaN         NaN
# 7243       NaN      NaN        NaN       NaN       NaN      NaN         NaN
# 7244       NaN      NaN        NaN       NaN       NaN      NaN         NaN
# 7245       NaN      NaN        NaN       NaN       NaN      NaN         NaN
# 7246       NaN      NaN        NaN       NaN       NaN      NaN         NaN
#
#      Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  \
# 0            ppm       40.0       NaN       NaN      NaN      0.2      ppm
# 1            ppm       32.0       NaN       NaN      NaN      0.3      ppm
# 2            ppm       12.0       NaN       NaN      NaN      0.8      ppm
# 3            ppm       14.0       NaN       NaN      NaN      0.4      ppm
# 4            ppm       33.0       NaN       NaN      NaN      0.4      ppm
# ...          ...        ...       ...       ...      ...      ...      ...
# 7242         NaN        NaN       NaN       NaN      NaN      1.1      ppm
# 7243         NaN        NaN       NaN       NaN      NaN      1.1      ppm
# 7244         NaN        NaN       NaN       NaN      NaN      0.2      ppm
# 7245         NaN        NaN       NaN       NaN      NaN      0.2      ppm
# 7246         NaN        NaN       NaN       NaN      NaN      0.2      ppm
#
#       CO AQI
# 0        2.0
# 1        3.0
# 2        9.0
# 3        5.0
# 4        5.0
# ...      ...
# 7242    13.0
# 7243    13.0
# 7244     2.0
# 7245     2.0
# 7246     2.0
#
# [7247 rows x 20 columns]
# Unnamed: 0     210
# Site Name      210
# Date           210
# DMean PM10     210
# PM10 Units     210
# PM10 AQI       210
# Lat            210
# Lng            210
# DMax NO2       210
# NO2 Units      210
# NO2 AQI        210
# DMax Ozone     210
# Ozone Units    210
# Ozone AQI      210
# DMax SO2       210
# SO2 Units      210
# SO2 AQI        210
# DMax CO        210
# CO Units       210
# CO AQI         210
# dtype: int64
# ['Los Angeles-North Main Street' 'Long Beach (Hudson)' 'LAX Hastings']

# %%
#print(df_01.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test_df=df_01.iloc[:,1:]
test_df
# Out:
#                          Site Name        Date  DMean PM10 PM10 Units  \
# 422  Los Angeles-North Main Street    1/1/2016        17.0   ug/m3 SC
# 423  Los Angeles-North Main Street    1/1/2016        17.0   ug/m3 SC
# 424  Los Angeles-North Main Street    1/7/2016         7.0   ug/m3 SC
# 425  Los Angeles-North Main Street   1/13/2016        22.0   ug/m3 SC
# 426  Los Angeles-North Main Street   1/13/2016        22.0   ug/m3 SC
# ..                             ...         ...         ...        ...
# 703                   LAX Hastings   12/2/2016        43.0   ug/m3 SC
# 704                   LAX Hastings   12/8/2016        25.0   ug/m3 SC
# 705                   LAX Hastings  12/14/2016        28.0   ug/m3 SC
# 706                   LAX Hastings  12/21/2016        19.0   ug/m3 SC
# 707                   LAX Hastings  12/26/2016        18.0   ug/m3 SC
#
#      PM10 AQI       Lat        Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone  \
# 422      16.0  34.06659 -118.22688      35.7       ppb     33.0       0.037
# 423      16.0  34.06659 -118.22688      35.7       ppb     33.0       0.037
# 424       6.0  34.06659 -118.22688      35.9       ppb     33.0       0.030
# 425      20.0  34.06659 -118.22688      47.6       ppb     44.0       0.017
# 426      20.0  34.06659 -118.22688      47.6       ppb     44.0       0.017
# ..        ...       ...        ...       ...       ...      ...         ...
# 703      40.0  33.95507 -118.43049      43.8       ppb     41.0       0.045
# 704      23.0  33.95507 -118.43049      35.0       ppb     33.0       0.038
# 705      26.0  33.95507 -118.43049      38.6       ppb     36.0       0.029
# 706      18.0  33.95507 -118.43049      33.3       ppb     31.0       0.024
# 707      17.0  33.95507 -118.43049      27.0       ppb     25.0       0.031
#
#     Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  \
# 422         ppm       34.0       0.6       ppb      0.0      0.8      ppm
# 423         ppm       34.0       0.6       ppb      0.0      0.8      ppm
# 424         ppm       28.0       0.0       ppb      0.0      0.3      ppm
# 425         ppm       16.0       0.9       ppb      0.0      1.0      ppm
# 426         ppm       16.0       0.9       ppb      0.0      1.0      ppm
# ..          ...        ...       ...       ...      ...      ...      ...
# 703         ppm       42.0       2.9       ppb      3.0      0.4      ppm
# 704         ppm       35.0       1.1       ppb      1.0      0.9      ppm
# 705         ppm       27.0       1.9       ppb      1.0      1.0      ppm
# 706         ppm       22.0       0.9       ppb      0.0      0.6      ppm
# 707         ppm       29.0       0.7       ppb      0.0      0.8      ppm
#
#      CO AQI
# 422     9.0
# 423     9.0
# 424     3.0
# 425    11.0
# 426    11.0
# ..      ...
# 703     5.0
# 704    10.0
# 705    11.0
# 706     7.0
# 707     9.0
#
# [210 rows x 19 columns]

# %%
df_02 = pd.read_csv("UrbanGroup/LA/LA2018DF.csv")
#print(df_02.count())
#drop the null rows
df_02 = df_02.dropna()
#print(df_02['Site Name'].unique())

# %%
#print(df_02.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test2_df=df_02.iloc[:,1:]
test2_df
# Out:
#                          Site Name        Date  DMean PM10 PM10 Units  \
# 408  Los Angeles-North Main Street    1/2/2018        66.0   ug/m3 SC
# 409  Los Angeles-North Main Street    1/2/2018        66.0   ug/m3 SC
# 410  Los Angeles-North Main Street    1/8/2018        22.0   ug/m3 SC
# 411  Los Angeles-North Main Street    1/8/2018        22.0   ug/m3 SC
# 412  Los Angeles-North Main Street   1/14/2018        18.0   ug/m3 SC
# ..                             ...         ...         ...        ...
# 660                   LAX Hastings   12/4/2018        18.0   ug/m3 SC
# 661                   LAX Hastings  12/10/2018        15.0   ug/m3 SC
# 662                   LAX Hastings  12/16/2018        21.0   ug/m3 SC
# 663                   LAX Hastings  12/22/2018        29.0   ug/m3 SC
# 664                   LAX Hastings  12/28/2018         9.0   ug/m3 SC
#
#      PM10 AQI       Lat        Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone  \
# 408      56.0  34.06659 -118.22688      61.8       ppb     58.0       0.024
# 409      56.0  34.06659 -118.22688      61.8       ppb     58.0       0.024
# 410      20.0  34.06659 -118.22688      35.0       ppb     33.0       0.017
# 411      20.0  34.06659 -118.22688      35.0       ppb     33.0       0.017
# 412      17.0  34.06659 -118.22688      45.8       ppb     42.0       0.040
# ..        ...       ...        ...       ...       ...      ...         ...
# 660      17.0  33.95507 -118.43049      43.6       ppb     41.0       0.038
# 661      14.0  33.95507 -118.43049      28.3       ppb     26.0       0.018
# 662      19.0  33.95507 -118.43049      34.5       ppb     32.0       0.036
# 663      27.0  33.95507 -118.43049      51.1       ppb     48.0       0.027
# 664       8.0  33.95507 -118.43049      27.6       ppb     25.0       0.038
#
#     Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  \
# 408         ppm       22.0       1.2       ppb      1.0      1.4      ppm
# 409         ppm       22.0       1.2       ppb      1.0      1.3      ppm
# 410         ppm       16.0       0.5       ppb      0.0      1.0      ppm
# 411         ppm       16.0       0.5       ppb      0.0      0.9      ppm
# 412         ppm       37.0       0.6       ppb      0.0      1.2      ppm
# ..          ...        ...       ...       ...      ...      ...      ...
# 660         ppm       35.0       0.9       ppb      0.0      0.6      ppm
# 661         ppm       17.0       0.8       ppb      0.0      0.5      ppm
# 662         ppm       33.0       3.6       ppb      4.0      1.1      ppm
# 663         ppm       25.0       2.7       ppb      3.0      1.0      ppm
# 664         ppm       35.0       0.9       ppb      0.0      0.1      ppm
#
#      CO AQI
# 408    16.0
# 409    15.0
# 410    11.0
# 411    10.0
# 412    14.0
# ..      ...
# 660     7.0
# 661     6.0
# 662    13.0
# 663    11.0
# 664     1.0
#
# [189 rows x 19 columns]

# %%
df_03 = pd.read_csv("UrbanGroup/LA/LA2020DF.csv")
#print(df_01.count())
#drop the null rows
df_03 = df_03.dropna()
print(df_03['Site Name'].unique())
# Out:
# ['Los Angeles-North Main Street' 'LAX Hastings']

# %%
#print(df_03.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test3_df=df_03.iloc[:,1:]
test3_df
# Out:
#                          Site Name        Date  DMean PM10 PM10 Units  \
# 402  Los Angeles-North Main Street    1/4/2020        37.0   ug/m3 SC
# 403  Los Angeles-North Main Street    1/4/2020        37.0   ug/m3 SC
# 404  Los Angeles-North Main Street    1/4/2020        37.0   ug/m3 SC
# 405  Los Angeles-North Main Street    1/4/2020        37.0   ug/m3 SC
# 406  Los Angeles-North Main Street   1/10/2020        27.0   ug/m3 SC
# ..                             ...         ...         ...        ...
# 624                   LAX Hastings   12/5/2020        27.0   ug/m3 SC
# 625                   LAX Hastings  12/11/2020        26.0   ug/m3 SC
# 626                   LAX Hastings  12/17/2020        27.0   ug/m3 SC
# 627                   LAX Hastings  12/23/2020        39.0   ug/m3 SC
# 628                   LAX Hastings  12/29/2020         8.0   ug/m3 SC
#
#      PM10 AQI       Lat        Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone  \
# 402      34.0  34.06659 -118.22688      40.6       ppb     38.0       0.022
# 403      34.0  34.06659 -118.22688      40.6       ppb     38.0       0.022
# 404      34.0  34.06659 -118.22688      40.4       ppb     38.0       0.022
# 405      34.0  34.06659 -118.22688      40.4       ppb     38.0       0.022
# 406      25.0  34.06659 -118.22688      37.5       ppb     35.0       0.019
# ..        ...       ...        ...       ...       ...      ...         ...
# 624      25.0  33.95507 -118.43049      39.0       ppb     37.0       0.027
# 625      24.0  33.95507 -118.43049      30.7       ppb     28.0       0.037
# 626      25.0  33.95507 -118.43049      50.9       ppb     47.0       0.031
# 627      36.0  33.95507 -118.43049      45.1       ppb     42.0       0.022
# 628       7.0  33.95507 -118.43049      28.9       ppb     26.0       0.030
#
#     Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  \
# 402         ppm       20.0       1.1       ppb      1.0      1.3      ppm
# 403         ppm       20.0       1.1       ppb      1.0      1.2      ppm
# 404         ppm       20.0       1.1       ppb      1.0      1.3      ppm
# 405         ppm       20.0       1.1       ppb      1.0      1.2      ppm
# 406         ppm       18.0       1.0       ppb      1.0      0.9      ppm
# ..          ...        ...       ...       ...      ...      ...      ...
# 624         ppm       25.0       1.2       ppb      1.0      0.7      ppm
# 625         ppm       34.0       0.4       ppb      0.0      0.6      ppm
# 626         ppm       29.0       3.0       ppb      4.0      1.1      ppm
# 627         ppm       20.0       2.1       ppb      3.0      0.7      ppm
# 628         ppm       28.0       1.4       ppb      1.0      0.4      ppm
#
#      CO AQI
# 402    15.0
# 403    14.0
# 404    15.0
# 405    14.0
# 406    10.0
# ..      ...
# 624     8.0
# 625     7.0
# 626    13.0
# 627     8.0
# 628     5.0
#
# [144 rows x 19 columns]

# %%
AllData=pd.DataFrame()
AllData=AllData.append(test_df)

# %%
AllData=AllData.append(test2_df)

# %%
AllData=AllData.append(test3_df)

# %%
AllData.to_csv("UrbanGroup/LA/LAMerged.csv")

# %%
AllData
# Out:
#                          Site Name        Date  DMean PM10 PM10 Units  \
# 422  Los Angeles-North Main Street    1/1/2016        17.0   ug/m3 SC
# 423  Los Angeles-North Main Street    1/1/2016        17.0   ug/m3 SC
# 424  Los Angeles-North Main Street    1/7/2016         7.0   ug/m3 SC
# 425  Los Angeles-North Main Street   1/13/2016        22.0   ug/m3 SC
# 426  Los Angeles-North Main Street   1/13/2016        22.0   ug/m3 SC
# ..                             ...         ...         ...        ...
# 624                   LAX Hastings   12/5/2020        27.0   ug/m3 SC
# 625                   LAX Hastings  12/11/2020        26.0   ug/m3 SC
# 626                   LAX Hastings  12/17/2020        27.0   ug/m3 SC
# 627                   LAX Hastings  12/23/2020        39.0   ug/m3 SC
# 628                   LAX Hastings  12/29/2020         8.0   ug/m3 SC
#
#      PM10 AQI       Lat        Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone  \
# 422      16.0  34.06659 -118.22688      35.7       ppb     33.0       0.037
# 423      16.0  34.06659 -118.22688      35.7       ppb     33.0       0.037
# 424       6.0  34.06659 -118.22688      35.9       ppb     33.0       0.030
# 425      20.0  34.06659 -118.22688      47.6       ppb     44.0       0.017
# 426      20.0  34.06659 -118.22688      47.6       ppb     44.0       0.017
# ..        ...       ...        ...       ...       ...      ...         ...
# 624      25.0  33.95507 -118.43049      39.0       ppb     37.0       0.027
# 625      24.0  33.95507 -118.43049      30.7       ppb     28.0       0.037
# 626      25.0  33.95507 -118.43049      50.9       ppb     47.0       0.031
# 627      36.0  33.95507 -118.43049      45.1       ppb     42.0       0.022
# 628       7.0  33.95507 -118.43049      28.9       ppb     26.0       0.030
#
#     Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  \
# 422         ppm       34.0       0.6       ppb      0.0      0.8      ppm
# 423         ppm       34.0       0.6       ppb      0.0      0.8      ppm
# 424         ppm       28.0       0.0       ppb      0.0      0.3      ppm
# 425         ppm       16.0       0.9       ppb      0.0      1.0      ppm
# 426         ppm       16.0       0.9       ppb      0.0      1.0      ppm
# ..          ...        ...       ...       ...      ...      ...      ...
# 624         ppm       25.0       1.2       ppb      1.0      0.7      ppm
# 625         ppm       34.0       0.4       ppb      0.0      0.6      ppm
# 626         ppm       29.0       3.0       ppb      4.0      1.1      ppm
# 627         ppm       20.0       2.1       ppb      3.0      0.7      ppm
# 628         ppm       28.0       1.4       ppb      1.0      0.4      ppm
#
#      CO AQI
# 422     9.0
# 423     9.0
# 424     3.0
# 425    11.0
# 426    11.0
# ..      ...
# 624     8.0
# 625     7.0
# 626    13.0
# 627     8.0
# 628     5.0
#
# [543 rows x 19 columns]

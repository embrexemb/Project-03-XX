# %%
import pandas as pd
import io
from io import StringIO

# %% [markdown]
# READ THE CSV AND PERFORM BASIC DATA CLEANING

# %%
df_01 = pd.read_csv("Metro/SE/SE2016DF.csv")
#print(df_01.count())
print(df_01)
#drop the null rows
#df_01 = df_01.dropna()
print(df_01.count())
print(df_01['Site Name'].unique())
# Out:
#       Unnamed: 0                              Site Name        Date  Lat  Lng  \
# 0              0                  Seattle-10th & Weller    1/1/2016  1.1  ppm
# 1              1                  Seattle-10th & Weller    1/2/2016  1.3  ppm
# 2              2                  Seattle-10th & Weller    1/3/2016  1.0  ppm
# 3              3                  Seattle-10th & Weller    1/4/2016  0.7  ppm
# 4              4                  Seattle-10th & Weller    1/5/2016  1.1  ppm
# ...          ...                                    ...         ...  ...  ...
# 1802        1802  MT RAINIER - JACKSON VISITIORS CENTER  12/26/2016  NaN  NaN
# 1803        1803  MT RAINIER - JACKSON VISITIORS CENTER  12/27/2016  NaN  NaN
# 1804        1804  MT RAINIER - JACKSON VISITIORS CENTER  12/28/2016  NaN  NaN
# 1805        1805  MT RAINIER - JACKSON VISITIORS CENTER  12/29/2016  NaN  NaN
# 1806        1806  MT RAINIER - JACKSON VISITIORS CENTER  12/30/2016  NaN  NaN
#
#       DMax NO2  NO2 Units     NO2 AQI DMax Ozone  Ozone Units Ozone AQI  \
# 0         13.0  47.597222 -122.319722        ppb         45.0      both
# 1         15.0  47.597222 -122.319722        ppb         40.0      both
# 2         11.0  47.597222 -122.319722        ppb         38.0      both
# 3          8.0  47.597222 -122.319722        ppb         29.0      both
# 4         13.0  47.597222 -122.319722        ppb         39.0      both
# ...        ...        ...         ...        ...          ...       ...
# 1802       NaN        NaN         NaN        NaN          NaN       NaN
# 1803       NaN        NaN         NaN        NaN          NaN       NaN
# 1804       NaN        NaN         NaN        NaN          NaN       NaN
# 1805       NaN        NaN         NaN        NaN          NaN       NaN
# 1806       NaN        NaN         NaN        NaN          NaN       NaN
#
#       DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  CO AQI
# 0          NaN       NaN      NaN      NaN      NaN     NaN
# 1          NaN       NaN      NaN      NaN      NaN     NaN
# 2          NaN       NaN      NaN      NaN      NaN     NaN
# 3          NaN       NaN      NaN      NaN      NaN     NaN
# 4          NaN       NaN      NaN      NaN      NaN     NaN
# ...        ...       ...      ...      ...      ...     ...
# 1802     0.042       ppm     39.0      NaN      NaN     NaN
# 1803     0.041       ppm     38.0      NaN      NaN     NaN
# 1804     0.046       ppm     43.0      NaN      NaN     NaN
# 1805     0.043       ppm     40.0      NaN      NaN     NaN
# 1806     0.044       ppm     41.0      NaN      NaN     NaN
#
# [1807 rows x 17 columns]
# Unnamed: 0     1807
# Site Name      1807
# Date           1807
# Lat             652
# Lng             652
# DMax NO2        652
# NO2 Units       652
# NO2 AQI         652
# DMax Ozone     1004
# Ozone Units    1004
# Ozone AQI      1049
# DMax SO2       1106
# SO2 Units      1106
# SO2 AQI        1106
# DMax CO         300
# CO Units        300
# CO AQI          300
# dtype: int64
# ['Seattle-10th & Weller' 'SEATTLE - BEACON HILL' 'Tacoma-S 36th St'
#  'ISSAQUAH -  LAKE SAMMAMISH (Wiithin Lake Sammamish State Park)'
#  'NORTH BEND - NORTH BEND WAY'
#  'ENUMCLAW - MUD MTN (Army Corp of Engineers site)'
#  'MT RAINIER - JACKSON VISITIORS CENTER']

# %%
#print(df_01.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test_df=df_01.iloc[:,1:]
test_df
# Out:
#                                   Site Name        Date  Lat  Lng  DMax NO2  \
# 0                     Seattle-10th & Weller    1/1/2016  1.1  ppm      13.0
# 1                     Seattle-10th & Weller    1/2/2016  1.3  ppm      15.0
# 2                     Seattle-10th & Weller    1/3/2016  1.0  ppm      11.0
# 3                     Seattle-10th & Weller    1/4/2016  0.7  ppm       8.0
# 4                     Seattle-10th & Weller    1/5/2016  1.1  ppm      13.0
# ...                                     ...         ...  ...  ...       ...
# 1802  MT RAINIER - JACKSON VISITIORS CENTER  12/26/2016  NaN  NaN       NaN
# 1803  MT RAINIER - JACKSON VISITIORS CENTER  12/27/2016  NaN  NaN       NaN
# 1804  MT RAINIER - JACKSON VISITIORS CENTER  12/28/2016  NaN  NaN       NaN
# 1805  MT RAINIER - JACKSON VISITIORS CENTER  12/29/2016  NaN  NaN       NaN
# 1806  MT RAINIER - JACKSON VISITIORS CENTER  12/30/2016  NaN  NaN       NaN
#
#       NO2 Units     NO2 AQI DMax Ozone  Ozone Units Ozone AQI  DMax SO2  \
# 0     47.597222 -122.319722        ppb         45.0      both       NaN
# 1     47.597222 -122.319722        ppb         40.0      both       NaN
# 2     47.597222 -122.319722        ppb         38.0      both       NaN
# 3     47.597222 -122.319722        ppb         29.0      both       NaN
# 4     47.597222 -122.319722        ppb         39.0      both       NaN
# ...         ...         ...        ...          ...       ...       ...
# 1802        NaN         NaN        NaN          NaN       NaN     0.042
# 1803        NaN         NaN        NaN          NaN       NaN     0.041
# 1804        NaN         NaN        NaN          NaN       NaN     0.046
# 1805        NaN         NaN        NaN          NaN       NaN     0.043
# 1806        NaN         NaN        NaN          NaN       NaN     0.044
#
#      SO2 Units  SO2 AQI  DMax CO CO Units  CO AQI
# 0          NaN      NaN      NaN      NaN     NaN
# 1          NaN      NaN      NaN      NaN     NaN
# 2          NaN      NaN      NaN      NaN     NaN
# 3          NaN      NaN      NaN      NaN     NaN
# 4          NaN      NaN      NaN      NaN     NaN
# ...        ...      ...      ...      ...     ...
# 1802       ppm     39.0      NaN      NaN     NaN
# 1803       ppm     38.0      NaN      NaN     NaN
# 1804       ppm     43.0      NaN      NaN     NaN
# 1805       ppm     40.0      NaN      NaN     NaN
# 1806       ppm     41.0      NaN      NaN     NaN
#
# [1807 rows x 16 columns]

# %%
df_02 = pd.read_csv("Metro/SE/SE2018DF.csv")
#print(df_02.count())
#drop the null rows
df_02 = df_02.dropna()
#print(df_02['Site Name'].unique())

# %%
#print(df_02.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test2_df=df_02.iloc[:,1:]
test2_df
# Out:
#                  Site Name        Date  DMean PM10 PM10 Units  PM10 AQI  \
# 0    SEATTLE - BEACON HILL    1/2/2018        13.0   ug/m3 SC      12.0
# 2    SEATTLE - BEACON HILL   1/11/2018         3.0   ug/m3 SC       3.0
# 3    SEATTLE - BEACON HILL   1/14/2018        11.0   ug/m3 SC      10.0
# 4    SEATTLE - BEACON HILL   1/20/2018         4.0   ug/m3 SC       4.0
# 5    SEATTLE - BEACON HILL   1/23/2018         3.0   ug/m3 SC       3.0
# ..                     ...         ...         ...        ...       ...
# 96   SEATTLE - BEACON HILL  12/13/2018         7.0   ug/m3 SC       6.0
# 98   SEATTLE - BEACON HILL  12/19/2018        11.0   ug/m3 SC      10.0
# 99   SEATTLE - BEACON HILL  12/22/2018         8.0   ug/m3 SC       7.0
# 100  SEATTLE - BEACON HILL  12/25/2018         9.0   ug/m3 SC       8.0
# 101  SEATTLE - BEACON HILL  12/28/2018         4.0   ug/m3 SC       4.0
#
#            Lat         Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone  \
# 0    47.568236 -122.308628      26.5       ppb     25.0       0.004
# 2    47.568236 -122.308628      24.1       ppb     23.0       0.032
# 3    47.568236 -122.308628      24.0       ppb     23.0       0.003
# 4    47.568236 -122.308628      14.8       ppb     13.0       0.036
# 5    47.568236 -122.308628      34.6       ppb     32.0       0.027
# ..         ...         ...       ...       ...      ...         ...
# 96   47.568236 -122.308628      26.0       ppb     25.0       0.019
# 98   47.568236 -122.308628      34.3       ppb     32.0       0.018
# 99   47.568236 -122.308628      27.3       ppb     25.0       0.028
# 100  47.568236 -122.308628      19.7       ppb     18.0       0.011
# 101  47.568236 -122.308628      23.9       ppb     22.0       0.029
#
#     Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  \
# 0           ppm        4.0       1.2       ppb      1.0      0.4      ppm
# 2           ppm       30.0       0.5       ppb      0.0      0.3      ppm
# 3           ppm        3.0       2.2       ppb      3.0      0.4      ppm
# 4           ppm       33.0       0.3       ppb      0.0      0.2      ppm
# 5           ppm       25.0       1.1       ppb      1.0      0.3      ppm
# ..          ...        ...       ...       ...      ...      ...      ...
# 96          ppm       18.0       0.8       ppb      0.0      0.3      ppm
# 98          ppm       17.0       1.6       ppb      1.0      0.4      ppm
# 99          ppm       26.0       1.4       ppb      1.0      0.3      ppm
# 100         ppm       10.0       1.1       ppb      1.0      0.3      ppm
# 101         ppm       27.0       0.8       ppb      0.0      0.4      ppm
#
#      CO AQI
# 0       5.0
# 2       3.0
# 3       5.0
# 4       2.0
# 5       3.0
# ..      ...
# 96      3.0
# 98      5.0
# 99      3.0
# 100     3.0
# 101     5.0
#
# [88 rows x 19 columns]

# %%
df_03 = pd.read_csv("Metro/SE/SE2020DF.csv")
#print(df_01.count())
#drop the null rows
df_03 = df_03.dropna()
print(df_03['Site Name'].unique())
# Out:
# ['SEATTLE - BEACON HILL']

# %%
#print(df_03.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test3_df=df_03.iloc[:,1:]
test3_df
# Out:
#                 Site Name        Date  DMean PM10 PM10 Units  PM10 AQI  \
# 0   SEATTLE - BEACON HILL    1/1/2020         4.0   ug/m3 SC       4.0
# 2   SEATTLE - BEACON HILL    1/7/2020         2.0   ug/m3 SC       2.0
# 3   SEATTLE - BEACON HILL   1/10/2020         2.0   ug/m3 SC       2.0
# 4   SEATTLE - BEACON HILL   1/13/2020         7.0   ug/m3 SC       6.0
# 5   SEATTLE - BEACON HILL   1/16/2020         7.0   ug/m3 SC       6.0
# ..                    ...         ...         ...        ...       ...
# 63  SEATTLE - BEACON HILL  12/14/2020         8.0   ug/m3 SC       7.0
# 64  SEATTLE - BEACON HILL  12/17/2020         6.0   ug/m3 SC       6.0
# 65  SEATTLE - BEACON HILL  12/20/2020         7.0   ug/m3 SC       6.0
# 67  SEATTLE - BEACON HILL  12/26/2020         5.0   ug/m3 SC       5.0
# 68  SEATTLE - BEACON HILL  12/29/2020        13.0   ug/m3 SC      12.0
#
#           Lat         Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone  \
# 0   47.568236 -122.308628       6.0       ppb      6.0       0.037
# 2   47.568236 -122.308628      23.1       ppb     22.0       0.034
# 3   47.568236 -122.308628      17.0       ppb     16.0       0.032
# 4   47.568236 -122.308628      20.1       ppb     19.0       0.026
# 5   47.568236 -122.308628      22.1       ppb     21.0       0.029
# ..        ...         ...       ...       ...      ...         ...
# 63  47.568236 -122.308628      27.1       ppb     25.0       0.025
# 64  47.568236 -122.308628       9.7       ppb      8.0       0.027
# 65  47.568236 -122.308628      21.7       ppb     20.0       0.034
# 67  47.568236 -122.308628      12.8       ppb     11.0       0.033
# 68  47.568236 -122.308628      21.5       ppb     20.0       0.004
#
#    Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  \
# 0          ppm       34.0       0.6       ppb      0.0      0.1      ppm
# 2          ppm       31.0       0.6       ppb      0.0      0.2      ppm
# 3          ppm       30.0       0.5       ppb      0.0      0.3      ppm
# 4          ppm       24.0       0.5       ppb      0.0      0.2      ppm
# 5          ppm       27.0       0.5       ppb      0.0      0.3      ppm
# ..         ...        ...       ...       ...      ...      ...      ...
# 63         ppm       23.0       1.3       ppb      1.0      0.3      ppm
# 64         ppm       25.0       1.1       ppb      1.0      0.2      ppm
# 65         ppm       31.0       0.2       ppb      0.0      0.3      ppm
# 67         ppm       31.0       0.1       ppb      0.0      0.2      ppm
# 68         ppm        4.0       0.8       ppb      0.0      0.5      ppm
#
#     CO AQI
# 0      1.0
# 2      2.0
# 3      3.0
# 4      2.0
# 5      3.0
# ..     ...
# 63     3.0
# 64     2.0
# 65     3.0
# 67     2.0
# 68     6.0
#
# [62 rows x 19 columns]

# %%
AllData=pd.DataFrame()
AllData=AllData.append(test_df)

# %%
AllData=AllData.append(test2_df)

# %%
AllData=AllData.append(test3_df)

# %%
AllData.to_csv("SEMerged.csv")

# %%
AllData
# Out:
#                 Site Name        Date        Lat         Lng  DMax NO2  \
# 0   Seattle-10th & Weller    1/1/2016   1.100000         ppm      13.0
# 1   Seattle-10th & Weller    1/2/2016   1.300000         ppm      15.0
# 2   Seattle-10th & Weller    1/3/2016   1.000000         ppm      11.0
# 3   Seattle-10th & Weller    1/4/2016   0.700000         ppm       8.0
# 4   Seattle-10th & Weller    1/5/2016   1.100000         ppm      13.0
# ..                    ...         ...        ...         ...       ...
# 63  SEATTLE - BEACON HILL  12/14/2020  47.568236 -122.308628      27.1
# 64  SEATTLE - BEACON HILL  12/17/2020  47.568236 -122.308628       9.7
# 65  SEATTLE - BEACON HILL  12/20/2020  47.568236 -122.308628      21.7
# 67  SEATTLE - BEACON HILL  12/26/2020  47.568236 -122.308628      12.8
# 68  SEATTLE - BEACON HILL  12/29/2020  47.568236 -122.308628      21.5
#
#     NO2 Units     NO2 AQI DMax Ozone Ozone Units Ozone AQI  DMax SO2  \
# 0   47.597222 -122.319722        ppb        45.0      both       NaN
# 1   47.597222 -122.319722        ppb        40.0      both       NaN
# 2   47.597222 -122.319722        ppb        38.0      both       NaN
# 3   47.597222 -122.319722        ppb        29.0      both       NaN
# 4   47.597222 -122.319722        ppb        39.0      both       NaN
# ..        ...         ...        ...         ...       ...       ...
# 63        ppb   25.000000      0.025         ppm      23.0       1.3
# 64        ppb    8.000000      0.027         ppm      25.0       1.1
# 65        ppb   20.000000      0.034         ppm      31.0       0.2
# 67        ppb   11.000000      0.033         ppm      31.0       0.1
# 68        ppb   20.000000      0.004         ppm       4.0       0.8
#
#    SO2 Units  SO2 AQI  DMax CO CO Units  CO AQI  DMean PM10 PM10 Units  \
# 0        NaN      NaN      NaN      NaN     NaN         NaN        NaN
# 1        NaN      NaN      NaN      NaN     NaN         NaN        NaN
# 2        NaN      NaN      NaN      NaN     NaN         NaN        NaN
# 3        NaN      NaN      NaN      NaN     NaN         NaN        NaN
# 4        NaN      NaN      NaN      NaN     NaN         NaN        NaN
# ..       ...      ...      ...      ...     ...         ...        ...
# 63       ppb      1.0      0.3      ppm     3.0         8.0   ug/m3 SC
# 64       ppb      1.0      0.2      ppm     2.0         6.0   ug/m3 SC
# 65       ppb      0.0      0.3      ppm     3.0         7.0   ug/m3 SC
# 67       ppb      0.0      0.2      ppm     2.0         5.0   ug/m3 SC
# 68       ppb      0.0      0.5      ppm     6.0        13.0   ug/m3 SC
#
#     PM10 AQI
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 63       7.0
# 64       6.0
# 65       6.0
# 67       5.0
# 68      12.0
#
# [1957 rows x 19 columns]

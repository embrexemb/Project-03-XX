# %%
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("CO-CarbonMonoxide/2016-Cheyenne-CO.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#        Date Source    Site ID  POC  Daily Max 8-hour CO Concentration UNITS  \
# 0  1/2/2016    AQS  560210100    1                                0.1   ppm
# 1  1/3/2016    AQS  560210100    1                                0.2   ppm
# 2  1/4/2016    AQS  560210100    1                                0.2   ppm
# 3  1/5/2016    AQS  560210100    1                                0.2   ppm
# 4  1/6/2016    AQS  560210100    1                                0.2   ppm
#
#    DAILY_AQI_VALUE       Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0                1  Cheyenne NCore               24               100
# 1                2  Cheyenne NCore               24               100
# 2                2  Cheyenne NCore               24               100
# 3                2  Cheyenne NCore               24               100
# 4                2  Cheyenne NCore               24               100
#
#    AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE     CBSA_NAME  STATE_CODE  \
# 0               42101    Carbon monoxide      16940  Cheyenne, WY          56
# 1               42101    Carbon monoxide      16940  Cheyenne, WY          56
# 2               42101    Carbon monoxide      16940  Cheyenne, WY          56
# 3               42101    Carbon monoxide      16940  Cheyenne, WY          56
# 4               42101    Carbon monoxide      16940  Cheyenne, WY          56
#
#      STATE  COUNTY_CODE   COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0  Wyoming           21  Laramie      41.182227     -104.778334
# 1  Wyoming           21  Laramie      41.182227     -104.778334
# 2  Wyoming           21  Laramie      41.182227     -104.778334
# 3  Wyoming           21  Laramie      41.182227     -104.778334
# 4  Wyoming           21  Laramie      41.182227     -104.778334

# %%
#files to load for 2016
Cheyenne_CO_2016 = "CO-CarbonMonoxide/2016-Cheyenne-CO.csv"
Cheyenne_NO_2016 = "NitrogenDioxide/2016-Cheyenne-NO@.csv"
Cheyenne_O_2016 = "Ozone/2016-Cheyenne-Ozone.csv"
#no lead for Cheyenne
Cheyenne_PM_2016 = "PM-ParticulateMatter/2016-Cheyenne-PM10.csv"
Cheyenne_SO_2016 = "SulfurDioxide/2016-Cheyenne-SO2.csv"

# %%
#files to load for 2018
Cheyenne_CO_2018 = "CO-CarbonMonoxide/2018-Cheyenne-CO.csv"
Cheyenne_NO_2018 = "NitrogenDioxide/2018-Cheyenne-NO@.csv"
Cheyenne_O_2018 = "Ozone/2018-Cheyenne-Ozone.csv"
#no lead for Cheyenne
Cheyenne_PM_2018 = "PM-ParticulateMatter/2018-Cheyenne-PM10.csv"
Cheyenne_SO_2018 = "SulfurDioxide/2018-Cheyenne-SO2.csv"

# %%
#files to load for 2020
Cheyenne_CO_2020 = "CO-CarbonMonoxide/2020-Cheyenne-CO.csv"
Cheyenne_NO_2020 = "NitrogenDioxide/2020-Cheyenne-NO@.csv"
Cheyenne_O_2020 = "Ozone/2020-Cheyenne-Ozone.csv"
#no lead for Cheyenne
Cheyenne_PM_2020 = "PM-ParticulateMatter/2020-Cheyenne-PM10.csv"
Cheyenne_SO_2020 = "SulfurDioxide/2020-Cheyenne-SO2.csv"

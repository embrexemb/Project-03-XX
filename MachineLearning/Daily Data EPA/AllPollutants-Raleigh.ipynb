# %%
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2016 Data

# %%
#files to load for 2016
Raleigh_CO_2016 = "CO-CarbonMonoxide/2016-Raleigh-CO.csv"
Raleigh_NO_2016 = "NitrogenDioxide/2016-Raleigh-NO2.csv"
Raleigh_O_2016 = "Ozone/2016-Raleigh-Ozone.csv"

#no lead for Raleigh

Raleigh_PM_2016 = "PM-ParticulateMatter/2016-Raleigh-PM10.csv"
Raleigh_SO_2016 = "SulfurDioxide/2016-Raleigh-SO2.csv"

#Read files into Pandas dataframe

df_2016_CO = pd.read_csv(Raleigh_CO_2016)
df_2016_NO = pd.read_csv(Raleigh_NO_2016)
df_2016_O = pd.read_csv(Raleigh_O_2016)
df_2016_PM = pd.read_csv(Raleigh_PM_2016)
df_2016_SO = pd.read_csv(Raleigh_SO_2016)


df_2016_PM=df_2016_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2016_CO=df_2016_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_NO=df_2016_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_O=df_2016_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_SO=df_2016_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]


df_2016_PM
# Out:
#             Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0    Millbrook School   8/27/2016                              7  ug/m3 SC
# 1    Millbrook School   8/28/2016                              7  ug/m3 SC
# 2    Millbrook School    9/1/2016                             15  ug/m3 SC
# 3    Millbrook School    9/2/2016                              9  ug/m3 SC
# 4    Millbrook School   9/10/2016                             23  ug/m3 SC
# ..                ...         ...                            ...       ...
# 295  Millbrook School   12/2/2016                              9  ug/m3 SC
# 296  Millbrook School   12/8/2016                              8  ug/m3 SC
# 297  Millbrook School  12/14/2016                             11  ug/m3 SC
# 298  Millbrook School  12/20/2016                              8  ug/m3 SC
# 299  Millbrook School  12/26/2016                             11  ug/m3 SC
#
#      DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# ...

# %% [markdown]
# print(df_2016_O.count())
# print(df_2016_CO.count())
# print(df_2016_NO.count())
# print(df_2016_PM.count())
# print(df_2016_SO.count())

# %% [markdown]
# Scratched
# #Cheyenne_2016_All = left.join(right, on=['Site Name'])
# #Cheyenne_2016_All = pd.concat([left, right], axis=1)
# #Cheyenne_2016_All = pd.merge(left.drop_duplicates(),right, how='inner', on='Site Name', validate='many_to_many')
# #C_2016=pd.merge(left.drop_duplicates(), right, how = 'inner',on=['col_1','col_2'])
# #C_2016=pd.concat([left, right],axis=1 )

# %%
left = df_2016_PM
right = df_2016_NO
Raleigh_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = Raleigh_2016_All
right = df_2016_O
Raleigh_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Raleigh_2016_All
right = df_2016_SO
Raleigh_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Raleigh_2016_All
right = df_2016_CO
Raleigh_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
Raleigh_2016_All.columns
# Out:
# Index(['Site Name', 'Date', 'Daily Mean PM10 Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'SITE_LATITUDE', 'SITE_LONGITUDE',
#        'Daily Max 1-hour NO2 Concentration', 'UNITS_y', 'DAILY_AQI_VALUE_y',
#        '_merge', 'Daily Max 8-hour Ozone Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'Daily Max 1-hour SO2 Concentration', 'UNITS_y',
#        'DAILY_AQI_VALUE_y', 'Daily Max 8-hour CO Concentration', 'UNITS',
#        'DAILY_AQI_VALUE'],
#       dtype='object')

# %%
Raleigh_2016_All.count()
# Out:
# Site Name                               1051
# Date                                    1051
# Daily Mean PM10 Concentration            300
# UNITS_x                                  300
# DAILY_AQI_VALUE_x                        300
# SITE_LATITUDE                            300
# SITE_LONGITUDE                           300
# Daily Max 1-hour NO2 Concentration       789
# UNITS_y                                  789
# DAILY_AQI_VALUE_y                        789
# _merge                                   793
# Daily Max 8-hour Ozone Concentration     689
# UNITS_x                                  689
# DAILY_AQI_VALUE_x                        689
# Daily Max 1-hour SO2 Concentration       450
# UNITS_y                                  450
# DAILY_AQI_VALUE_y                        450
# Daily Max 8-hour CO Concentration        447
# UNITS                                    447
# DAILY_AQI_VALUE                          447
# dtype: int64

# %%
#print(Raleigh_2016_All)

# %%
Raleigh_2016_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
Raleigh_2016_All.count()
# Out:
# Site Name      1051
# Date           1051
# DMean PM10      300
# PM10 Units      300
# PM10 AQI        300
# Lat             300
# Lng             300
# DMax NO2        789
# NO2 Units       789
# NO2 AQI         789
# Merged          793
# DMax Ozone      689
# Ozone Units     689
# Ozone AQI       689
# DMax SO2        450
# SO2 Units       450
# SO2 AQI         450
# DMax CO         447
# CO Units        447
# CO AQI          447
# dtype: int64

# %%
Raleigh_2016_All.drop('Merged',axis=1,inplace=True)
Raleigh_2016_All.to_csv("RA2016DF.csv")

# %% [markdown]
# 2018 Data

# %%
#files to load for 2018

Raleigh_CO_2018 = "CO-CarbonMonoxide/2018-Raleigh-CO.csv"
Raleigh_NO_2018 = "NitrogenDioxide/2018-Raleigh-NO2.csv"
Raleigh_O_2018= "Ozone/2018-Raleigh-Ozone.csv"
Raleigh_PM_2018 = "PM-ParticulateMatter/2018-Raleigh-PM10.csv"
Raleigh_SO_2018 = "SulfurDioxide/2018-Raleigh-SO2.csv"

#Read files into Pandas dataframe

df_2018_CO = pd.read_csv(Raleigh_CO_2018)
df_2018_NO = pd.read_csv(Raleigh_NO_2018)
df_2018_O = pd.read_csv(Raleigh_O_2018)
df_2018_PM = pd.read_csv(Raleigh_PM_2018)
df_2018_SO = pd.read_csv(Raleigh_SO_2018)

df_2018_PM=df_2018_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2018_CO=df_2018_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_NO=df_2018_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_O=df_2018_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_SO=df_2018_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]


df_2018_PM
# Out:
#             Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0    Millbrook School    1/1/2018                              7  ug/m3 SC
# 1    Millbrook School    1/2/2018                             12  ug/m3 SC
# 2    Millbrook School    1/3/2018                             20  ug/m3 SC
# 3    Millbrook School    1/4/2018                             13  ug/m3 SC
# 4    Millbrook School    1/5/2018                             12  ug/m3 SC
# ..                ...         ...                            ...       ...
# 583  Millbrook School  12/27/2018                             15  ug/m3 SC
# 584  Millbrook School  12/28/2018                             12  ug/m3 SC
# 585  Millbrook School  12/29/2018                             12  ug/m3 SC
# 586  Millbrook School  12/30/2018                             19  ug/m3 SC
# 587  Millbrook School  12/31/2018                             22  ug/m3 SC
#
#      DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# ...

# %%
Raleigh_2018_All=[]

# %%
left = df_2018_PM
right = df_2018_NO
Raleigh_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = Raleigh_2018_All
right = df_2018_O
Raleigh_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Raleigh_2018_All
right = df_2018_SO
Raleigh_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Raleigh_2018_All
right = df_2018_CO
Raleigh_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
Raleigh_2018_All.columns
# Out:
# Index(['Site Name', 'Date', 'Daily Mean PM10 Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'SITE_LATITUDE', 'SITE_LONGITUDE',
#        'Daily Max 1-hour NO2 Concentration', 'UNITS_y', 'DAILY_AQI_VALUE_y',
#        '_merge', 'Daily Max 8-hour Ozone Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'Daily Max 1-hour SO2 Concentration', 'UNITS_y',
#        'DAILY_AQI_VALUE_y', 'Daily Max 8-hour CO Concentration', 'UNITS',
#        'DAILY_AQI_VALUE'],
#       dtype='object')

# %%
Raleigh_2018_All.count()
# Out:
# Site Name                               1183
# Date                                    1183
# Daily Mean PM10 Concentration            588
# UNITS_x                                  588
# DAILY_AQI_VALUE_x                        588
# SITE_LATITUDE                            588
# SITE_LONGITUDE                           588
# Daily Max 1-hour NO2 Concentration       908
# UNITS_y                                  908
# DAILY_AQI_VALUE_y                        908
# _merge                                   931
# Daily Max 8-hour Ozone Concentration     811
# UNITS_x                                  811
# DAILY_AQI_VALUE_x                        811
# Daily Max 1-hour SO2 Concentration       577
# UNITS_y                                  577
# DAILY_AQI_VALUE_y                        577
# Daily Max 8-hour CO Concentration        936
# UNITS                                    936
# DAILY_AQI_VALUE                          936
# dtype: int64

# %%
Raleigh_2018_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
Raleigh_2018_All.drop('Merged',axis=1,inplace=True)
Raleigh_2018_All.to_csv("RA2018DF.csv")

# %% [markdown]
# 2020 Data

# %%
#files to load for 2020

Raleigh_CO_2020 = "CO-CarbonMonoxide/2020-Raleigh-CO.csv"
Raleigh_NO_2020 = "NitrogenDioxide/2020-Raleigh-NO2.csv"
Raleigh_O_2020 = "Ozone/2020-Raleigh-Ozone.csv"
#no lead for Raleigh
Raleigh_PM_2020 = "PM-ParticulateMatter/2020-Raleigh-PM10.csv"
Raleigh_SO_2020 = "SulfurDioxide/2020-Raleigh-SO2.csv"

#Read files into Pandas dataframe

df_2020_CO = pd.read_csv(Raleigh_CO_2020)
df_2020_NO = pd.read_csv(Raleigh_NO_2020)
df_2020_O = pd.read_csv(Raleigh_O_2020)
df_2020_PM = pd.read_csv(Raleigh_PM_2020)
df_2020_SO = pd.read_csv(Raleigh_SO_2020)


df_2020_PM=df_2020_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2020_CO=df_2020_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_NO=df_2020_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_O=df_2020_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_SO=df_2020_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]


df_2020_PM
# Out:
#             Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0    Millbrook School    1/1/2020                              8  ug/m3 SC
# 1    Millbrook School    1/2/2020                             13  ug/m3 SC
# 2    Millbrook School    1/3/2020                             12  ug/m3 SC
# 3    Millbrook School    1/4/2020                              3  ug/m3 SC
# 4    Millbrook School    1/5/2020                              6  ug/m3 SC
# ..                ...         ...                            ...       ...
# 693  Millbrook School  12/27/2020                             19  ug/m3 SC
# 694  Millbrook School  12/28/2020                             18  ug/m3 SC
# 695  Millbrook School  12/29/2020                             13  ug/m3 SC
# 696  Millbrook School  12/30/2020                             12  ug/m3 SC
# 697  Millbrook School  12/31/2020                             14  ug/m3 SC
#
#      DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# ...

# %%
Raleigh_2020_All = []

# %%
left = df_2020_PM
right = df_2020_NO
Raleigh_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = Raleigh_2020_All
right = df_2020_O
Raleigh_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Raleigh_2020_All
right = df_2020_SO
Raleigh_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = Raleigh_2020_All
right = df_2020_CO
Raleigh_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
Raleigh_2020_All.count()
# Out:
# Site Name                               1312
# Date                                    1312
# Daily Mean PM10 Concentration            698
# UNITS_x                                  698
# DAILY_AQI_VALUE_x                        698
# SITE_LATITUDE                            698
# SITE_LONGITUDE                           698
# Daily Max 1-hour NO2 Concentration       986
# UNITS_y                                  986
# DAILY_AQI_VALUE_y                        986
# _merge                                  1032
# Daily Max 8-hour Ozone Concentration     945
# UNITS_x                                  945
# DAILY_AQI_VALUE_x                        945
# Daily Max 1-hour SO2 Concentration       643
# UNITS_y                                  643
# DAILY_AQI_VALUE_y                        643
# Daily Max 8-hour CO Concentration       1061
# UNITS                                   1061
# DAILY_AQI_VALUE                         1061
# dtype: int64

# %%
Raleigh_2020_All.tail()
# Out:
#        Site Name        Date  Daily Mean PM10 Concentration UNITS_x  \
# 1307  Triple Oak  11/29/2020                            NaN     NaN
# 1308  Triple Oak  11/30/2020                            NaN     NaN
# 1309  Triple Oak   12/1/2020                            NaN     NaN
# 1310  Triple Oak   12/2/2020                            NaN     NaN
# 1311  Triple Oak  12/10/2020                            NaN     NaN
#
#       DAILY_AQI_VALUE_x  SITE_LATITUDE  SITE_LONGITUDE  \
# 1307                NaN            NaN             NaN
# 1308                NaN            NaN             NaN
# 1309                NaN            NaN             NaN
# 1310                NaN            NaN             NaN
# 1311                NaN            NaN             NaN
#
#       Daily Max 1-hour NO2 Concentration UNITS_y  DAILY_AQI_VALUE_y _merge  \
# 1307                                 NaN     NaN                NaN    NaN
# ...

# %%
Raleigh_2020_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
Raleigh_2020_All.columns
# Out:
# Index(['Site Name', 'Date', 'DMean PM10', 'PM10 Units', 'PM10 AQI', 'Lat',
#        'Lng', 'DMax NO2', 'NO2 Units', 'NO2 AQI', 'Merged', 'DMax Ozone',
#        'Ozone Units', 'Ozone AQI', 'DMax SO2', 'SO2 Units', 'SO2 AQI',
#        'DMax CO', 'CO Units', 'CO AQI'],
#       dtype='object')

# %%
Raleigh_2020_All.drop('Merged',axis=1,inplace=True)
Raleigh_2020_All.to_csv("RA2020DF.csv")

# %%
import pandas as pd
import io
from io import StringIO

# %% [markdown]
# READ THE CSV AND PERFORM BASIC DATA CLEANING

# %%
#df_01 = pd.read_csv("SE2016DF.csv")
#print(df_01.count())
#print(df_01)
#drop the null rows
#df_01 = df_01.dropna()
#print(df_01.count())
#print(df_01['Site Name'].unique())

# %%
#print(df_01.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
#test_df=df_01.iloc[:,1:]
#test_df

# %%
df_02 = pd.read_csv("SE2018DF.csv")
#print(df_02.count())
#drop the null rows
#df_02 = df_02.dropna()
#print(df_02['Site Name'].unique())

# %%
#print(df_02.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test2_df=df_02.iloc[:,1:]
test2_df
# Out:
#                   Site Name       Date  DMean PM10 PM10 Units  PM10 AQI  \
# 0     SEATTLE - BEACON HILL   1/2/2018        13.0   ug/m3 SC      12.0
# 1     SEATTLE - BEACON HILL   1/5/2018         8.0   ug/m3 SC       7.0
# 2     SEATTLE - BEACON HILL  1/11/2018         3.0   ug/m3 SC       3.0
# 3     SEATTLE - BEACON HILL  1/14/2018        11.0   ug/m3 SC      10.0
# 4     SEATTLE - BEACON HILL  1/20/2018         4.0   ug/m3 SC       4.0
# ...                     ...        ...         ...        ...       ...
# 1808  Seattle-10th & Weller  3/10/2018         NaN        NaN       NaN
# 1809  Seattle-10th & Weller   5/2/2018         NaN        NaN       NaN
# 1810  Seattle-10th & Weller  6/20/2018         NaN        NaN       NaN
# 1811  Seattle-10th & Weller   9/4/2018         NaN        NaN       NaN
# 1812  Seattle-10th & Weller  9/10/2018         NaN        NaN       NaN
#
#             Lat         Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone  \
# 0     47.568236 -122.308628      26.5       ppb     25.0       0.004
# 1     47.568236 -122.308628      30.9       ppb     28.0         NaN
# 2     47.568236 -122.308628      24.1       ppb     23.0       0.032
# 3     47.568236 -122.308628      24.0       ppb     23.0       0.003
# 4     47.568236 -122.308628      14.8       ppb     13.0       0.036
# ...         ...         ...       ...       ...      ...         ...
# 1808        NaN         NaN       NaN       NaN      NaN         NaN
# 1809        NaN         NaN       NaN       NaN      NaN         NaN
# 1810        NaN         NaN       NaN       NaN      NaN         NaN
# 1811        NaN         NaN       NaN       NaN      NaN         NaN
# 1812        NaN         NaN       NaN       NaN      NaN         NaN
#
#      Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  \
# 0            ppm        4.0       1.2       ppb      1.0      0.4      ppm
# 1            NaN        NaN       2.4       ppb      3.0      0.8      ppm
# 2            ppm       30.0       0.5       ppb      0.0      0.3      ppm
# 3            ppm        3.0       2.2       ppb      3.0      0.4      ppm
# 4            ppm       33.0       0.3       ppb      0.0      0.2      ppm
# ...          ...        ...       ...       ...      ...      ...      ...
# 1808         NaN        NaN       NaN       NaN      NaN      0.8      ppm
# 1809         NaN        NaN       NaN       NaN      NaN      0.6      ppm
# 1810         NaN        NaN       NaN       NaN      NaN      0.7      ppm
# 1811         NaN        NaN       NaN       NaN      NaN      0.5      ppm
# 1812         NaN        NaN       NaN       NaN      NaN      0.4      ppm
#
#       CO AQI
# 0        5.0
# 1        9.0
# 2        3.0
# 3        5.0
# 4        2.0
# ...      ...
# 1808     9.0
# 1809     7.0
# 1810     8.0
# 1811     6.0
# 1812     5.0
#
# [1813 rows x 19 columns]

# %%
df_03 = pd.read_csv("SE2020DF.csv")
#print(df_01.count())
#drop the null rows
#df_03 = df_03.dropna()
print(df_03['Site Name'].unique())
# Out:
# ['SEATTLE - BEACON HILL' 'Seattle-10th & Weller' 'Tacoma-S 36th St'
#  'ISSAQUAH -  LAKE SAMMAMISH (Wiithin Lake Sammamish State Park)'
#  'NORTH BEND - NORTH BEND WAY'
#  'ENUMCLAW - MUD MTN (Army Corp of Engineers site)'
#  'MT RAINIER - JACKSON VISITIORS CENTER']

# %%
#print(df_03.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test3_df=df_03.iloc[:,1:]
test3_df
# Out:
#                                   Site Name        Date  DMean PM10  \
# 0                     SEATTLE - BEACON HILL    1/1/2020         4.0
# 1                     SEATTLE - BEACON HILL    1/4/2020         7.0
# 2                     SEATTLE - BEACON HILL    1/7/2020         2.0
# 3                     SEATTLE - BEACON HILL   1/10/2020         2.0
# 4                     SEATTLE - BEACON HILL   1/13/2020         7.0
# ...                                     ...         ...         ...
# 1864  MT RAINIER - JACKSON VISITIORS CENTER  12/29/2020         NaN
# 1865  MT RAINIER - JACKSON VISITIORS CENTER  12/30/2020         NaN
# 1866  MT RAINIER - JACKSON VISITIORS CENTER  12/31/2020         NaN
# 1867                  Seattle-10th & Weller    1/6/2020         NaN
# 1868                  Seattle-10th & Weller   1/20/2020         NaN
#
#      PM10 Units  PM10 AQI        Lat         Lng  DMax NO2 NO2 Units  NO2 AQI  \
# 0      ug/m3 SC       4.0  47.568236 -122.308628       6.0       ppb      6.0
# 1      ug/m3 SC       6.0  47.568236 -122.308628      10.9       ppb      9.0
# 2      ug/m3 SC       2.0  47.568236 -122.308628      23.1       ppb     22.0
# 3      ug/m3 SC       2.0  47.568236 -122.308628      17.0       ppb     16.0
# 4      ug/m3 SC       6.0  47.568236 -122.308628      20.1       ppb     19.0
# ...         ...       ...        ...         ...       ...       ...      ...
# 1864        NaN       NaN        NaN         NaN       NaN       NaN      NaN
# 1865        NaN       NaN        NaN         NaN       NaN       NaN      NaN
# 1866        NaN       NaN        NaN         NaN       NaN       NaN      NaN
# 1867        NaN       NaN        NaN         NaN       NaN       NaN      NaN
# 1868        NaN       NaN        NaN         NaN       NaN       NaN      NaN
#
#       DMax Ozone Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO  \
# 0          0.037         ppm       34.0       0.6       ppb      0.0      0.1
# 1          0.034         ppm       31.0       NaN       NaN      NaN      0.2
# 2          0.034         ppm       31.0       0.6       ppb      0.0      0.2
# 3          0.032         ppm       30.0       0.5       ppb      0.0      0.3
# 4          0.026         ppm       24.0       0.5       ppb      0.0      0.2
# ...          ...         ...        ...       ...       ...      ...      ...
# 1864       0.044         ppm       41.0       NaN       NaN      NaN      NaN
# 1865       0.041         ppm       38.0       NaN       NaN      NaN      NaN
# 1866       0.038         ppm       35.0       NaN       NaN      NaN      NaN
# 1867         NaN         NaN        NaN       NaN       NaN      NaN      0.3
# 1868         NaN         NaN        NaN       NaN       NaN      NaN      0.7
#
#      CO Units  CO AQI
# 0         ppm     1.0
# 1         ppm     2.0
# 2         ppm     2.0
# 3         ppm     3.0
# 4         ppm     2.0
# ...       ...     ...
# 1864      NaN     NaN
# 1865      NaN     NaN
# 1866      NaN     NaN
# 1867      ppm     3.0
# 1868      ppm     8.0
#
# [1869 rows x 19 columns]

# %%
AllData=pd.DataFrame()
#AllData=AllData.append(test_df)

# %%
AllData=AllData.append(test2_df)

# %%
AllData=AllData.append(test3_df)

# %%
AllData.to_csv("SEMerged.csv")

# %%
AllData
# Out:
#                                   Site Name        Date  DMean PM10  \
# 0                     SEATTLE - BEACON HILL    1/2/2018        13.0
# 1                     SEATTLE - BEACON HILL    1/5/2018         8.0
# 2                     SEATTLE - BEACON HILL   1/11/2018         3.0
# 3                     SEATTLE - BEACON HILL   1/14/2018        11.0
# 4                     SEATTLE - BEACON HILL   1/20/2018         4.0
# ...                                     ...         ...         ...
# 1864  MT RAINIER - JACKSON VISITIORS CENTER  12/29/2020         NaN
# 1865  MT RAINIER - JACKSON VISITIORS CENTER  12/30/2020         NaN
# 1866  MT RAINIER - JACKSON VISITIORS CENTER  12/31/2020         NaN
# 1867                  Seattle-10th & Weller    1/6/2020         NaN
# 1868                  Seattle-10th & Weller   1/20/2020         NaN
#
#      PM10 Units  PM10 AQI        Lat         Lng  DMax NO2 NO2 Units  NO2 AQI  \
# 0      ug/m3 SC      12.0  47.568236 -122.308628      26.5       ppb     25.0
# 1      ug/m3 SC       7.0  47.568236 -122.308628      30.9       ppb     28.0
# 2      ug/m3 SC       3.0  47.568236 -122.308628      24.1       ppb     23.0
# 3      ug/m3 SC      10.0  47.568236 -122.308628      24.0       ppb     23.0
# 4      ug/m3 SC       4.0  47.568236 -122.308628      14.8       ppb     13.0
# ...         ...       ...        ...         ...       ...       ...      ...
# 1864        NaN       NaN        NaN         NaN       NaN       NaN      NaN
# 1865        NaN       NaN        NaN         NaN       NaN       NaN      NaN
# 1866        NaN       NaN        NaN         NaN       NaN       NaN      NaN
# 1867        NaN       NaN        NaN         NaN       NaN       NaN      NaN
# 1868        NaN       NaN        NaN         NaN       NaN       NaN      NaN
#
#       DMax Ozone Ozone Units  Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO  \
# 0          0.004         ppm        4.0       1.2       ppb      1.0      0.4
# 1            NaN         NaN        NaN       2.4       ppb      3.0      0.8
# 2          0.032         ppm       30.0       0.5       ppb      0.0      0.3
# 3          0.003         ppm        3.0       2.2       ppb      3.0      0.4
# 4          0.036         ppm       33.0       0.3       ppb      0.0      0.2
# ...          ...         ...        ...       ...       ...      ...      ...
# 1864       0.044         ppm       41.0       NaN       NaN      NaN      NaN
# 1865       0.041         ppm       38.0       NaN       NaN      NaN      NaN
# 1866       0.038         ppm       35.0       NaN       NaN      NaN      NaN
# 1867         NaN         NaN        NaN       NaN       NaN      NaN      0.3
# 1868         NaN         NaN        NaN       NaN       NaN      NaN      0.7
#
#      CO Units  CO AQI
# 0         ppm     5.0
# 1         ppm     9.0
# 2         ppm     3.0
# 3         ppm     5.0
# 4         ppm     2.0
# ...       ...     ...
# 1864      NaN     NaN
# 1865      NaN     NaN
# 1866      NaN     NaN
# 1867      ppm     3.0
# 1868      ppm     8.0
#
# [3682 rows x 19 columns]

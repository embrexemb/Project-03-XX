# %%
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2016 Data

# %%
#files to load for 2016
LA_CO_2016 = "CO-CarbonMonoxide/2016-LA-CO.csv"
LA_NO_2016 = "NitrogenDioxide/2016-LA-NO2.csv"
LA_O_2016 = "Ozone/2016-LA-Ozone.csv"
LA_PB_2016 = "PB-Lead/2016-LA-PB.csv"
LA_PM_2016 = "PM-ParticulateMatter/2016-LA-PM10.csv"
LA_SO_2016 = "SulfurDioxide/2016-LA-SO2.csv"

#Read files into Pandas dataframe

df_2016_CO = pd.read_csv(LA_CO_2016)
df_2016_NO = pd.read_csv(LA_NO_2016)
df_2016_O = pd.read_csv(LA_O_2016)
df_2016_PB = pd.read_csv(LA_PB_2016)
df_2016_PM = pd.read_csv(LA_PM_2016)
df_2016_SO = pd.read_csv(LA_SO_2016)


df_2016_PM=df_2016_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2016_CO=df_2016_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_NO=df_2016_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_O=df_2016_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_SO=df_2016_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2016_PB=df_2016_PB[['Site Name','Date','Daily Mean Pb Concentration','UNITS','DAILY_AQI_VALUE']]


df_2016_PM
# Out:
#           Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0             Azusa    1/1/2016                             12  ug/m3 SC
# 1             Azusa    1/7/2016                              7  ug/m3 SC
# 2             Azusa   1/13/2016                             32  ug/m3 SC
# 3             Azusa   1/19/2016                             24  ug/m3 SC
# 4             Azusa   1/25/2016                             16  ug/m3 SC
# ...             ...         ...                            ...       ...
# 1545  Mission Viejo   12/2/2016                             45  ug/m3 SC
# 1546  Mission Viejo   12/8/2016                             26  ug/m3 SC
# 1547  Mission Viejo  12/14/2016                             39  ug/m3 SC
# 1548  Mission Viejo  12/20/2016                             16  ug/m3 SC
# 1549  Mission Viejo  12/26/2016                             12  ug/m3 SC
#
#       DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# ...

# %%
left = df_2016_PM
right = df_2016_NO
LA_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = LA_2016_All
right = df_2016_O
LA_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = LA_2016_All
right = df_2016_SO
LA_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = LA_2016_All
right = df_2016_CO
LA_2016_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
LA_2016_All.columns
# Out:
# Index(['Site Name', 'Date', 'Daily Mean PM10 Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'SITE_LATITUDE', 'SITE_LONGITUDE',
#        'Daily Max 1-hour NO2 Concentration', 'UNITS_y', 'DAILY_AQI_VALUE_y',
#        '_merge', 'Daily Max 8-hour Ozone Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'Daily Max 1-hour SO2 Concentration', 'UNITS_y',
#        'DAILY_AQI_VALUE_y', 'Daily Max 8-hour CO Concentration', 'UNITS',
#        'DAILY_AQI_VALUE'],
#       dtype='object')

# %%
LA_2016_All.count()
# Out:
# Site Name                               7247
# Date                                    7247
# Daily Mean PM10 Concentration           1597
# UNITS_x                                 1597
# DAILY_AQI_VALUE_x                       1597
# SITE_LATITUDE                           1597
# SITE_LONGITUDE                          1597
# Daily Max 1-hour NO2 Concentration      6689
# UNITS_y                                 6689
# DAILY_AQI_VALUE_y                       6689
# _merge                                  6845
# Daily Max 8-hour Ozone Concentration    6311
# UNITS_x                                 6311
# DAILY_AQI_VALUE_x                       6311
# Daily Max 1-hour SO2 Concentration      1707
# UNITS_y                                 1707
# DAILY_AQI_VALUE_y                       1707
# Daily Max 8-hour CO Concentration       6561
# UNITS                                   6561
# DAILY_AQI_VALUE                         6561
# dtype: int64

# %%
#print(ElPaso_2016_All)

# %%
LA_2016_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
LA_2016_All.count()
# Out:
# Site Name      7247
# Date           7247
# DMean PM10     1597
# PM10 Units     1597
# PM10 AQI       1597
# Lat            1597
# Lng            1597
# DMax NO2       6689
# NO2 Units      6689
# NO2 AQI        6689
# Merged         6845
# DMax Ozone     6311
# Ozone Units    6311
# Ozone AQI      6311
# DMax SO2       1707
# SO2 Units      1707
# SO2 AQI        1707
# DMax CO        6561
# CO Units       6561
# CO AQI         6561
# dtype: int64

# %%
LA_2016_All.drop('Merged',axis=1,inplace=True)
LA_2016_All.to_csv("LA2016DF.csv")

# %% [markdown]
# 2018 Data

# %%
#files to load for 2018

LA_CO_2018 = "CO-CarbonMonoxide/2018-LA-CO.csv"
LA_NO_2018 = "NitrogenDioxide/2018-LA-NO2.csv"
LA_O_2018 = "Ozone/2018-LA-Ozone.csv"
LA_PB_2018 = "PB-Lead/2018-LA-PB.csv"
LA_PM_2018 = "PM-ParticulateMatter/2018-LA-PM10.csv"
LA_SO_2018 = "SulfurDioxide/2018-LA-SO2.csv"


#Read files into Pandas dataframe

df_2018_CO = pd.read_csv(LA_CO_2018)
df_2018_NO = pd.read_csv(LA_NO_2018)
df_2018_O = pd.read_csv(LA_O_2018)
df_2018_PB = pd.read_csv(LA_PB_2018)
df_2018_PM = pd.read_csv(LA_PM_2018)
df_2018_SO = pd.read_csv(LA_SO_2018)

df_2018_PM=df_2018_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2018_CO=df_2018_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_NO=df_2018_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_O=df_2018_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_SO=df_2018_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_PB=df_2018_PB[['Site Name','Date','Daily Mean Pb Concentration','UNITS','DAILY_AQI_VALUE']]

df_2018_PM
# Out:
#           Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0             Azusa    1/2/2018                             78  ug/m3 SC
# 1             Azusa    1/8/2018                             14  ug/m3 SC
# 2             Azusa   1/14/2018                             10  ug/m3 SC
# 3             Azusa   1/20/2018                             13  ug/m3 SC
# 4             Azusa   1/26/2018                             16  ug/m3 SC
# ...             ...         ...                            ...       ...
# 1462  Mission Viejo   12/4/2018                             12  ug/m3 SC
# 1463  Mission Viejo  12/10/2018                             22  ug/m3 SC
# 1464  Mission Viejo  12/16/2018                             22  ug/m3 SC
# 1465  Mission Viejo  12/22/2018                             30  ug/m3 SC
# 1466  Mission Viejo  12/28/2018                             11  ug/m3 SC
#
#       DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# ...

# %%
LA_2018_All=[]

# %%
left = df_2018_PM
right = df_2018_NO
LA_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = LA_2018_All
right = df_2018_O
LA_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = LA_2018_All
right = df_2018_SO
LA_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = LA_2018_All
right = df_2018_CO
LA_2018_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
LA_2018_All.columns
# Out:
# Index(['Site Name', 'Date', 'Daily Mean PM10 Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'SITE_LATITUDE', 'SITE_LONGITUDE',
#        'Daily Max 1-hour NO2 Concentration', 'UNITS_y', 'DAILY_AQI_VALUE_y',
#        '_merge', 'Daily Max 8-hour Ozone Concentration', 'UNITS_x',
#        'DAILY_AQI_VALUE_x', 'Daily Max 1-hour SO2 Concentration', 'UNITS_y',
#        'DAILY_AQI_VALUE_y', 'Daily Max 8-hour CO Concentration', 'UNITS',
#        'DAILY_AQI_VALUE'],
#       dtype='object')

# %%
LA_2018_All.count()
# Out:
# Site Name                               6907
# Date                                    6907
# Daily Mean PM10 Concentration           1506
# UNITS_x                                 1506
# DAILY_AQI_VALUE_x                       1506
# SITE_LATITUDE                           1506
# SITE_LONGITUDE                          1506
# Daily Max 1-hour NO2 Concentration      6177
# UNITS_y                                 6177
# DAILY_AQI_VALUE_y                       6177
# _merge                                  6327
# Daily Max 8-hour Ozone Concentration    5930
# UNITS_x                                 5930
# DAILY_AQI_VALUE_x                       5930
# Daily Max 1-hour SO2 Concentration      1324
# UNITS_y                                 1324
# DAILY_AQI_VALUE_y                       1324
# Daily Max 8-hour CO Concentration       6351
# UNITS                                   6351
# DAILY_AQI_VALUE                         6351
# dtype: int64

# %%
LA_2018_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
LA_2018_All.drop('Merged',axis=1,inplace=True)
LA_2018_All.to_csv("LA2018DF.csv")

# %% [markdown]
# 2020 Data

# %%
#files to load for 2020

LA_CO_2020 = "CO-CarbonMonoxide/2020-LA-CO.csv"
LA_NO_2020 = "NitrogenDioxide/2020-LA-NO2.csv"
LA_O_2020 = "Ozone/2020-LA-Ozone.csv"
LA_PB_2020 = "PB-Lead/2020-LA-PB.csv"
LA_PM_2020 = "PM-ParticulateMatter/2020-LA-PM10.csv"
LA_SO_2020 = "SulfurDioxide/2020-LA-SO2.csv"

#Read files into Pandas dataframe

df_2020_CO = pd.read_csv(LA_CO_2020)
df_2020_NO = pd.read_csv(LA_NO_2020)
df_2020_O = pd.read_csv(LA_O_2020)
df_2020_PB = pd.read_csv(LA_PB_2020)
df_2020_PM = pd.read_csv(LA_PM_2020)
df_2020_SO = pd.read_csv(LA_SO_2020)


df_2020_PM=df_2020_PM[['Site Name','Date','Daily Mean PM10 Concentration','UNITS','DAILY_AQI_VALUE', 'SITE_LATITUDE','SITE_LONGITUDE' ]]

df_2020_CO=df_2020_CO[['Site Name','Date','Daily Max 8-hour CO Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_NO=df_2020_NO[['Site Name','Date','Daily Max 1-hour NO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_O=df_2020_O[['Site Name','Date','Daily Max 8-hour Ozone Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_SO=df_2020_SO[['Site Name','Date','Daily Max 1-hour SO2 Concentration','UNITS','DAILY_AQI_VALUE']]

df_2020_PB=df_2020_PB[['Site Name','Date','Daily Mean Pb Concentration','UNITS','DAILY_AQI_VALUE']]


df_2020_PM
# Out:
#           Site Name        Date  Daily Mean PM10 Concentration     UNITS  \
# 0             Azusa    1/4/2020                             25  ug/m3 SC
# 1             Azusa   1/10/2020                             20  ug/m3 SC
# 2             Azusa   1/16/2020                             32  ug/m3 SC
# 3             Azusa   1/22/2020                             21  ug/m3 SC
# 4             Azusa   1/28/2020                             23  ug/m3 SC
# ...             ...         ...                            ...       ...
# 1382  Mission Viejo   12/5/2020                             16  ug/m3 SC
# 1383  Mission Viejo  12/11/2020                             17  ug/m3 SC
# 1384  Mission Viejo  12/17/2020                             11  ug/m3 SC
# 1385  Mission Viejo  12/23/2020                             22  ug/m3 SC
# 1386  Mission Viejo  12/29/2020                              4  ug/m3 SC
#
#       DAILY_AQI_VALUE  SITE_LATITUDE  SITE_LONGITUDE
# ...

# %%
LA_2020_All = []

# %%
left = df_2020_PM
right = df_2020_NO
LA_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer', indicator=True)

# %%
left = LA_2020_All
right = df_2020_O
LA_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = LA_2020_All
right = df_2020_SO
LA_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
left = LA_2020_All
right = df_2020_CO
LA_2020_All = pd.merge(left, right, on=['Site Name','Date'],how='outer')

# %%
LA_2020_All.count()
# Out:
# Site Name                               7782
# Date                                    7782
# Daily Mean PM10 Concentration           1470
# UNITS_x                                 1470
# DAILY_AQI_VALUE_x                       1470
# SITE_LATITUDE                           1470
# SITE_LONGITUDE                          1470
# Daily Max 1-hour NO2 Concentration      7271
# UNITS_y                                 7271
# DAILY_AQI_VALUE_y                       7271
# _merge                                  7392
# Daily Max 8-hour Ozone Concentration    6849
# UNITS_x                                 6849
# DAILY_AQI_VALUE_x                       6849
# Daily Max 1-hour SO2 Concentration      1393
# UNITS_y                                 1393
# DAILY_AQI_VALUE_y                       1393
# Daily Max 8-hour CO Concentration       6582
# UNITS                                   6582
# DAILY_AQI_VALUE                         6582
# dtype: int64

# %%
LA_2020_All.tail()
# Out:
#           Site Name       Date  Daily Mean PM10 Concentration UNITS_x  \
# 7777  Mission Viejo   2/6/2020                            NaN     NaN
# 7778       La Habra  1/27/2020                            NaN     NaN
# 7779       La Habra  3/10/2020                            NaN     NaN
# 7780       La Habra  6/11/2020                            NaN     NaN
# 7781       La Habra  7/13/2020                            NaN     NaN
#
#       DAILY_AQI_VALUE_x  SITE_LATITUDE  SITE_LONGITUDE  \
# 7777                NaN            NaN             NaN
# 7778                NaN            NaN             NaN
# 7779                NaN            NaN             NaN
# 7780                NaN            NaN             NaN
# 7781                NaN            NaN             NaN
#
#       Daily Max 1-hour NO2 Concentration UNITS_y  DAILY_AQI_VALUE_y _merge  \
# 7777                                 NaN     NaN                NaN    NaN
# ...

# %%
LA_2020_All.columns=['Site Name','Date','DMean PM10','PM10 Units','PM10 AQI','Lat','Lng','DMax NO2','NO2 Units','NO2 AQI','Merged','DMax Ozone','Ozone Units','Ozone AQI','DMax SO2','SO2 Units','SO2 AQI','DMax CO','CO Units','CO AQI']

# %%
LA_2020_All.columns
# Out:
# Index(['Site Name', 'Date', 'DMean PM10', 'PM10 Units', 'PM10 AQI', 'Lat',
#        'Lng', 'DMax NO2', 'NO2 Units', 'NO2 AQI', 'Merged', 'DMax Ozone',
#        'Ozone Units', 'Ozone AQI', 'DMax SO2', 'SO2 Units', 'SO2 AQI',
#        'DMax CO', 'CO Units', 'CO AQI'],
#       dtype='object')

# %%
LA_2020_All.drop('Merged',axis=1,inplace=True)
LA_2020_All.to_csv("LA2020DF.csv")

# %%
import pandas as pd
import io
from io import StringIO

# %% [markdown]
# READ THE CSV AND PERFORM BASIC DATA CLEANING

# %%
df_01 = pd.read_csv("Ch2016DF.csv")
#print(df_01.count())
#print(df_01)
#drop the null rows
df_01 = df_01.dropna()
#print(df_01.count())
print(df_01['Site Name'].unique())
# Out:
# ['Cheyenne NCore']

# %%
#print(df_01.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test_df=df_01.iloc[:,1:]
test_df
# Out:
#           Site Name        Date  DMean PM10 PM10 Units  PM10 AQI        Lat  \
# 430  Cheyenne NCore    1/2/2016         7.0   ug/m3 SC       6.0  41.182227
# 431  Cheyenne NCore    1/3/2016         9.0   ug/m3 SC       8.0  41.182227
# 432  Cheyenne NCore    1/4/2016        14.0   ug/m3 SC      13.0  41.182227
# 433  Cheyenne NCore    1/5/2016         8.0   ug/m3 SC       7.0  41.182227
# 434  Cheyenne NCore    1/6/2016         8.0   ug/m3 SC       7.0  41.182227
# ..              ...         ...         ...        ...       ...        ...
# 752  Cheyenne NCore  12/26/2016         5.0   ug/m3 SC       5.0  41.182227
# 753  Cheyenne NCore  12/27/2016         9.0   ug/m3 SC       8.0  41.182227
# 754  Cheyenne NCore  12/28/2016         5.0   ug/m3 SC       5.0  41.182227
# 755  Cheyenne NCore  12/29/2016         8.0   ug/m3 SC       7.0  41.182227
# 756  Cheyenne NCore  12/30/2016         6.0   ug/m3 SC       6.0  41.182227
#
#             Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone Ozone Units  \
# 430 -104.778334      13.6       ppb     12.0       0.047         ppm
# 431 -104.778334      36.0       ppb     34.0       0.041         ppm
# 432 -104.778334      39.5       ppb     37.0       0.035         ppm
# 433 -104.778334      11.3       ppb     10.0       0.040         ppm
# 434 -104.778334      25.4       ppb     24.0       0.039         ppm
# ..          ...       ...       ...      ...         ...         ...
# 752 -104.778334       6.8       ppb      6.0       0.048         ppm
# 753 -104.778334      12.9       ppb     11.0       0.054         ppm
# 754 -104.778334       1.1       ppb      1.0       0.045         ppm
# 755 -104.778334      19.6       ppb     18.0       0.044         ppm
# 756 -104.778334       6.1       ppb      6.0       0.046         ppm
#
#      Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  CO AQI
# 430       44.0      -0.2       ppb      0.0      0.1      ppm     1.0
# 431       38.0       0.5       ppb      0.0      0.2      ppm     2.0
# 432       32.0       1.2       ppb      1.0      0.2      ppm     2.0
# 433       37.0       0.1       ppb      0.0      0.2      ppm     2.0
# 434       36.0       0.3       ppb      0.0      0.2      ppm     2.0
# ..         ...       ...       ...      ...      ...      ...     ...
# 752       44.0       0.4       ppb      0.0      0.1      ppm     1.0
# 753       50.0       1.2       ppb      1.0      0.1      ppm     1.0
# 754       42.0       0.3       ppb      0.0      0.1      ppm     1.0
# 755       41.0       0.2       ppb      0.0      0.2      ppm     2.0
# 756       43.0       0.0       ppb      0.0      0.1      ppm     1.0
#
# [247 rows x 19 columns]

# %%
df_02 = pd.read_csv("Ch2018DF.csv")
#print(df_02.count())
#drop the null rows
df_02 = df_02.dropna()
#print(df_02['Site Name'].unique())

# %%
#print(df_02.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test2_df=df_02.iloc[:,1:]
test2_df
# Out:
#           Site Name        Date  DMean PM10 PM10 Units  PM10 AQI        Lat  \
# 214  Cheyenne NCore    1/1/2018        15.0   ug/m3 SC      14.0  41.182227
# 215  Cheyenne NCore    1/2/2018         5.0   ug/m3 SC       5.0  41.182227
# 216  Cheyenne NCore    1/3/2018        13.0   ug/m3 SC      12.0  41.182227
# 217  Cheyenne NCore    1/4/2018        14.0   ug/m3 SC      13.0  41.182227
# 218  Cheyenne NCore    1/5/2018        10.0   ug/m3 SC       9.0  41.182227
# ..              ...         ...         ...        ...       ...        ...
# 562  Cheyenne NCore  12/26/2018         5.0   ug/m3 SC       5.0  41.182227
# 563  Cheyenne NCore  12/27/2018         3.0   ug/m3 SC       3.0  41.182227
# 564  Cheyenne NCore  12/28/2018         9.0   ug/m3 SC       8.0  41.182227
# 565  Cheyenne NCore  12/29/2018        11.0   ug/m3 SC      10.0  41.182227
# 566  Cheyenne NCore  12/30/2018         5.0   ug/m3 SC       5.0  41.182227
#
#             Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone Ozone Units  \
# 214 -104.778334      29.0       ppb     27.0       0.036         ppm
# 215 -104.778334       5.6       ppb      5.0       0.046         ppm
# 216 -104.778334      25.8       ppb     24.0       0.039         ppm
# 217 -104.778334      28.7       ppb     26.0       0.037         ppm
# 218 -104.778334      23.3       ppb     22.0       0.037         ppm
# ..          ...       ...       ...      ...         ...         ...
# 562 -104.778334       6.6       ppb      6.0       0.029         ppm
# 563 -104.778334       1.5       ppb      1.0       0.036         ppm
# 564 -104.778334      28.1       ppb     26.0       0.033         ppm
# 565 -104.778334      36.9       ppb     34.0       0.041         ppm
# 566 -104.778334       1.0       ppb      1.0       0.040         ppm
#
#      Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  CO AQI
# 214       33.0       0.5       ppb      0.0      0.2      ppm     2.0
# 215       43.0       0.4       ppb      0.0      0.2      ppm     2.0
# 216       36.0       0.2       ppb      0.0      0.2      ppm     2.0
# 217       34.0       0.2       ppb      0.0      0.2      ppm     2.0
# 218       34.0       0.6       ppb      0.0      0.2      ppm     2.0
# ..         ...       ...       ...      ...      ...      ...     ...
# 562       27.0       0.6       ppb      0.0      0.1      ppm     1.0
# 563       33.0       0.6       ppb      0.0      0.1      ppm     1.0
# 564       31.0       0.5       ppb      0.0      0.2      ppm     2.0
# 565       38.0       0.8       ppb      0.0      0.2      ppm     2.0
# 566       37.0       0.6       ppb      0.0      0.1      ppm     1.0
#
# [311 rows x 19 columns]

# %%
df_03 = pd.read_csv("Ch2020DF.csv")
#print(df_01.count())
#drop the null rows
df_03 = df_03.dropna()
print(df_03['Site Name'].unique())
# Out:
# ['Cheyenne NCore']

# %%
#print(df_03.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test3_df=df_03.iloc[:,1:]
test3_df
# Out:
#           Site Name        Date  DMean PM10 PM10 Units  PM10 AQI        Lat  \
# 0    Cheyenne NCore    1/1/2020         4.0   ug/m3 SC       4.0  41.182227
# 3    Cheyenne NCore    1/2/2020         0.0   ug/m3 SC       0.0  41.182227
# 5    Cheyenne NCore    1/3/2020         3.0   ug/m3 SC       3.0  41.182227
# 7    Cheyenne NCore    1/4/2020         5.0   ug/m3 SC       5.0  41.182227
# 20   Cheyenne NCore    1/9/2020         6.0   ug/m3 SC       6.0  41.182227
# ..              ...         ...         ...        ...       ...        ...
# 616  Cheyenne NCore  12/25/2020         2.0   ug/m3 SC       2.0  41.182227
# 617  Cheyenne NCore  12/26/2020         3.0   ug/m3 SC       3.0  41.182227
# 618  Cheyenne NCore  12/27/2020         1.0   ug/m3 SC       1.0  41.182227
# 619  Cheyenne NCore  12/28/2020         4.0   ug/m3 SC       4.0  41.182227
# 621  Cheyenne NCore  12/30/2020         4.0   ug/m3 SC       4.0  41.182227
#
#             Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone Ozone Units  \
# 0   -104.778334       1.5       ppb      1.0       0.036         ppm
# 3   -104.778334       2.8       ppb      2.0       0.035         ppm
# 5   -104.778334       4.2       ppb      4.0       0.034         ppm
# 7   -104.778334       2.8       ppb      2.0       0.035         ppm
# 20  -104.778334      16.6       ppb     15.0       0.034         ppm
# ..          ...       ...       ...      ...         ...         ...
# 616 -104.778334      11.9       ppb     10.0       0.041         ppm
# 617 -104.778334       4.2       ppb      4.0       0.042         ppm
# 618 -104.778334       2.3       ppb      2.0       0.037         ppm
# 619 -104.778334      10.3       ppb      9.0       0.031         ppm
# 621 -104.778334      15.1       ppb     14.0       0.044         ppm
#
#      Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  CO AQI
# 0         33.0       0.6       ppb      0.0      0.1      ppm     1.0
# 3         32.0       0.2       ppb      0.0      0.1      ppm     1.0
# 5         31.0       0.0       ppb      0.0      0.1      ppm     1.0
# 7         32.0       0.0       ppb      0.0      0.1      ppm     1.0
# 20        31.0      -1.2       ppb      0.0      0.2      ppm     2.0
# ..         ...       ...       ...      ...      ...      ...     ...
# 616       38.0       0.1       ppb      0.0      0.1      ppm     1.0
# 617       39.0       0.3       ppb      0.0      0.1      ppm     1.0
# 618       34.0       0.2       ppb      0.0      0.1      ppm     1.0
# 619       29.0       0.2       ppb      0.0      0.1      ppm     1.0
# 621       41.0       0.2       ppb      0.0      0.1      ppm     1.0
#
# [290 rows x 19 columns]

# %%
AllData=pd.DataFrame()
AllData=AllData.append(test_df)

# %%
AllData=AllData.append(test2_df)

# %%
AllData=AllData.append(test3_df)

# %%
AllData.to_csv("CHMerged.csv")

# %%
AllData
# Out:
#           Site Name        Date  DMean PM10 PM10 Units  PM10 AQI        Lat  \
# 430  Cheyenne NCore    1/2/2016         7.0   ug/m3 SC       6.0  41.182227
# 431  Cheyenne NCore    1/3/2016         9.0   ug/m3 SC       8.0  41.182227
# 432  Cheyenne NCore    1/4/2016        14.0   ug/m3 SC      13.0  41.182227
# 433  Cheyenne NCore    1/5/2016         8.0   ug/m3 SC       7.0  41.182227
# 434  Cheyenne NCore    1/6/2016         8.0   ug/m3 SC       7.0  41.182227
# ..              ...         ...         ...        ...       ...        ...
# 616  Cheyenne NCore  12/25/2020         2.0   ug/m3 SC       2.0  41.182227
# 617  Cheyenne NCore  12/26/2020         3.0   ug/m3 SC       3.0  41.182227
# 618  Cheyenne NCore  12/27/2020         1.0   ug/m3 SC       1.0  41.182227
# 619  Cheyenne NCore  12/28/2020         4.0   ug/m3 SC       4.0  41.182227
# 621  Cheyenne NCore  12/30/2020         4.0   ug/m3 SC       4.0  41.182227
#
#             Lng  DMax NO2 NO2 Units  NO2 AQI  DMax Ozone Ozone Units  \
# 430 -104.778334      13.6       ppb     12.0       0.047         ppm
# 431 -104.778334      36.0       ppb     34.0       0.041         ppm
# 432 -104.778334      39.5       ppb     37.0       0.035         ppm
# 433 -104.778334      11.3       ppb     10.0       0.040         ppm
# 434 -104.778334      25.4       ppb     24.0       0.039         ppm
# ..          ...       ...       ...      ...         ...         ...
# 616 -104.778334      11.9       ppb     10.0       0.041         ppm
# 617 -104.778334       4.2       ppb      4.0       0.042         ppm
# 618 -104.778334       2.3       ppb      2.0       0.037         ppm
# 619 -104.778334      10.3       ppb      9.0       0.031         ppm
# 621 -104.778334      15.1       ppb     14.0       0.044         ppm
#
#      Ozone AQI  DMax SO2 SO2 Units  SO2 AQI  DMax CO CO Units  CO AQI
# 430       44.0      -0.2       ppb      0.0      0.1      ppm     1.0
# 431       38.0       0.5       ppb      0.0      0.2      ppm     2.0
# 432       32.0       1.2       ppb      1.0      0.2      ppm     2.0
# 433       37.0       0.1       ppb      0.0      0.2      ppm     2.0
# 434       36.0       0.3       ppb      0.0      0.2      ppm     2.0
# ..         ...       ...       ...      ...      ...      ...     ...
# 616       38.0       0.1       ppb      0.0      0.1      ppm     1.0
# 617       39.0       0.3       ppb      0.0      0.1      ppm     1.0
# 618       34.0       0.2       ppb      0.0      0.1      ppm     1.0
# 619       29.0       0.2       ppb      0.0      0.1      ppm     1.0
# 621       41.0       0.2       ppb      0.0      0.1      ppm     1.0
#
# [848 rows x 19 columns]

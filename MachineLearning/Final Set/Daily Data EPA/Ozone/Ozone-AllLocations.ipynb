# %%
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
#files for Ozone
Cheyenne_O = "2020-Cheyenne-Ozone.csv"
ElPaso_O = "2020-ElPaso-Ozone.csv"
LA_O = "2020-LA-Ozone.csv"
NY_O = "2020-NY-Ozone.csv"
Raleigh_O = "2020-Raleigh-Ozone.csv"
Seattle_O = "2020-Seattle-Ozone.csv"

# %%
#Read into Pandas Dataframe
df_CH = pd.read_csv(Cheyenne_O)
df_EP = pd.read_csv(ElPaso_O)
df_LA = pd.read_csv(LA_O)
df_NY = pd.read_csv(NY_O)
df_RA = pd.read_csv(Raleigh_O)
df_SE = pd.read_csv(Seattle_O)

# %%
df_CH.dropna()
df_CH.head()
# Out:
#        Date Source    Site ID  POC  Daily Max 8-hour Ozone Concentration  \
# 0  1/1/2020    AQS  560210003    1                                 0.043
# 1  1/2/2020    AQS  560210003    1                                 0.039
# 2  1/3/2020    AQS  560210003    1                                 0.039
# 3  1/4/2020    AQS  560210003    1                                 0.040
# 4  1/5/2020    AQS  560210003    1                                 0.038
#
#   UNITS  DAILY_AQI_VALUE              Site Name  DAILY_OBS_COUNT  \
# 0   ppm               40  Laramie County Mobile               17
# 1   ppm               36  Laramie County Mobile               17
# 2   ppm               36  Laramie County Mobile               17
# 3   ppm               37  Laramie County Mobile               17
# 4   ppm               35  Laramie County Mobile               17
#
#    PERCENT_COMPLETE  AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE  \
# ...

# %%
df_CH=df_CH[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 8-hour Ozone Concentration','DAILY_AQI_VALUE']]
df_CH.to_csv('CH2020.csv')

# %%
df_SE=df_SE[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 8-hour Ozone Concentration','DAILY_AQI_VALUE']]
df_EP=df_EP[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 8-hour Ozone Concentration','DAILY_AQI_VALUE']]
df_LA=df_LA[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 8-hour Ozone Concentration','DAILY_AQI_VALUE']]
df_NY=df_NY[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 8-hour Ozone Concentration','DAILY_AQI_VALUE']]
df_RA=df_RA[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Max 8-hour Ozone Concentration','DAILY_AQI_VALUE']]

# %%
#df_CH['Site Name'].unique()

# %%
df_SE.dropna()
df_SE['Site Name'].unique()
df_SE.to_csv('SE2020.csv')

# %%
df_EP.dropna()
df_EP['Site Name'].unique()
df_EP.to_csv('EP2020.csv')

# %%
df_LA.dropna()
df_LA['Site Name'].unique()
df_LA.to_csv('LA2020.csv')

# %%
df_NY.dropna()
df_NY['Site Name'].unique()

df_NY.to_csv('Y2020.csv' ,encoding='ISO-8859-1')

# %%
df_RA.dropna()
df_RA['Site Name'].unique()
df_RA.to_csv('RA2020.csv')

# %%
#files are cleaned - merge manually

# %%
import pandas as pd
import io
from io import StringIO

# %% [markdown]
# READ THE CSV AND PERFORM BASIC DATA CLEANING

# %%
df_01 = pd.read_csv("Raleigh2016DF.csv")
#print(df_01.count())
#print(df_01)
#drop the null rows
df_01 = df_01.dropna()
#print(df_01.count())
print(df_01['Site Name'].unique())
# Out:
# ['Millbrook School']

# %%
#print(df_01.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test_df=df_01.iloc[:,1:]
test_df
# Out:
#             Site Name       Date  DMean PM10  PM_UNITS  PM10 AQI  PM-WEIGHT  \
# 0    Millbrook School  8/27/2016         7.0  ug/m3 SC       6.0        1.0
# 1    Millbrook School  8/28/2016         7.0  ug/m3 SC       6.0        1.0
# 2    Millbrook School  8/28/2016        15.0  ug/m3 SC      14.0        1.0
# 3    Millbrook School  8/28/2016        15.0  ug/m3 SC      14.0        1.0
# 5    Millbrook School   9/2/2016         9.0  ug/m3 SC       8.0        1.0
# ..                ...        ...         ...       ...       ...        ...
# 295  Millbrook School   9/6/2016        14.0  ug/m3 SC      13.0        1.0
# 296  Millbrook School   9/9/2016        23.0  ug/m3 SC      21.0        1.0
# 297  Millbrook School   9/9/2016        23.0  ug/m3 SC      21.0        1.0
# 298  Millbrook School  9/21/2016         4.0  ug/m3 SC       4.0        1.0
# 299  Millbrook School  9/21/2016         3.0  ug/m3 SC       3.0        1.0
#
#            LAt        Lng  DMax NO2 NO2 Units  ...  Ozone AQI  OZONE-WEIGHT  \
# 0    35.856111 -78.574167       8.0       ppb  ...       46.0          17.0
# 1    35.856111 -78.574167       2.0       ppb  ...       44.0          17.0
# 2    35.856111 -78.574167       2.0       ppb  ...       44.0          17.0
# 3    35.856111 -78.574167       2.0       ppb  ...       44.0          17.0
# 5    35.856111 -78.574167       6.7       ppb  ...       27.0          17.0
# ..         ...        ...       ...       ...  ...        ...           ...
# 295  35.856111 -78.574167      20.6       ppb  ...       64.0          17.0
# 296  35.856111 -78.574167      15.5       ppb  ...       74.0          17.0
# 297  35.856111 -78.574167      15.5       ppb  ...       74.0          17.0
# 298  35.856111 -78.574167       2.5       ppb  ...       21.0          17.0
# 299  35.856111 -78.574167       2.5       ppb  ...       21.0          17.0
#
#      DMax SO2 SO2 Units  SO2 AQI  SO2-WEIGHT  DMax CO CO Units  CO AQI  \
# 0         0.3       ppb      0.0        23.0      0.3      ppm     3.0
# 1         0.2       ppb      0.0        23.0      0.2      ppm     2.0
# 2         0.2       ppb      0.0        23.0      0.2      ppm     2.0
# 3         0.2       ppb      0.0        23.0      0.2      ppm     2.0
# 5         0.2       ppb      0.0        23.0      0.2      ppm     2.0
# ..        ...       ...      ...         ...      ...      ...     ...
# 295       0.8       ppb      0.0        23.0      0.4      ppm     5.0
# 296       0.5       ppb      0.0        23.0      0.3      ppm     3.0
# 297       0.5       ppb      0.0        23.0      0.3      ppm     3.0
# 298       0.2       ppb      0.0        23.0      0.1      ppm     1.0
# 299       0.2       ppb      0.0        23.0      0.1      ppm     1.0
#
#      CO-WEIGHT
# 0         24.0
# 1         24.0
# 2         24.0
# 3         24.0
# 5         24.0
# ..         ...
# 295       24.0
# 296       24.0
# 297       24.0
# 298       24.0
# 299       24.0
#
# [264 rows x 24 columns]

# %%
df_02 = pd.read_csv("Raleigh2018DF.csv")
#print(df_02.count())
#drop the null rows
df_02 = df_02.dropna()
#print(df_02['Site Name'].unique())

# %%
#print(df_02.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test2_df=df_02.iloc[:,1:]
test2_df
# Out:
#             Site Name       Date  DMean PM10  PM_UNITS  PM10 AQI  PM-WEIGHT  \
# 0    Millbrook School   1/1/2018         7.0  ug/m3 SC       6.0        1.0
# 1    Millbrook School   1/2/2018        12.0  ug/m3 SC      11.0        1.0
# 2    Millbrook School   1/3/2018        20.0  ug/m3 SC      19.0        1.0
# 3    Millbrook School   1/4/2018        13.0  ug/m3 SC      12.0        1.0
# 4    Millbrook School   1/5/2018        12.0  ug/m3 SC      11.0        1.0
# ..                ...        ...         ...       ...       ...        ...
# 581  Millbrook School  7/28/2018        18.0  ug/m3 SC      17.0        1.0
# 582  Millbrook School  7/29/2018        16.0  ug/m3 SC      15.0        1.0
# 583  Millbrook School  7/30/2018        12.0  ug/m3 SC      11.0        1.0
# 584  Millbrook School  7/31/2018        16.0  ug/m3 SC      15.0        1.0
# 587  Millbrook School   8/3/2018        13.0  ug/m3 SC      12.0        1.0
#
#            LAt        Lng  DMax NO2 NO2 Units  ...  Ozone AQI  OZONE-WEIGHT  \
# 0    35.856111 -78.574167       7.2       ppb  ...       34.0          17.0
# 1    35.856111 -78.574167      33.6       ppb  ...       31.0          17.0
# 2    35.856111 -78.574167      30.3       ppb  ...       30.0          17.0
# 3    35.856111 -78.574167       5.4       ppb  ...       32.0          17.0
# 4    35.856111 -78.574167      18.2       ppb  ...       33.0          17.0
# ..         ...        ...       ...       ...  ...        ...           ...
# 581  35.856111 -78.574167       8.0       ppb  ...       43.0          17.0
# 582  35.856111 -78.574167       4.8       ppb  ...       37.0          17.0
# 583  35.856111 -78.574167       4.2       ppb  ...       29.0          17.0
# 584  35.856111 -78.574167       5.2       ppb  ...       31.0          17.0
# 587  35.856111 -78.574167       6.0       ppb  ...       19.0          17.0
#
#      DMax SO2 SO2 Units  SO2 AQI  SO2-WEIGHT  DMax CO CO Units  CO AQI  \
# 0         2.0       ppb      3.0        23.0      0.2      ppm     2.0
# 1         1.8       ppb      1.0        23.0      0.7      ppm     8.0
# 2         2.5       ppb      3.0        21.0      0.9      ppm    10.0
# 3         1.9       ppb      1.0        23.0      0.2      ppm     2.0
# 4         1.3       ppb      1.0        23.0      0.2      ppm     2.0
# ..        ...       ...      ...         ...      ...      ...     ...
# 581       0.1       ppb      0.0        23.0      0.3      ppm     3.0
# 582       0.1       ppb      0.0        23.0      0.3      ppm     3.0
# 583       0.1       ppb      0.0        23.0      0.2      ppm     2.0
# 584       0.0       ppb      0.0        23.0      0.2      ppm     2.0
# 587       0.0       ppb      0.0        23.0      0.2      ppm     2.0
#
#      CO-WEIGHT
# 0         18.0
# 1         24.0
# 2         24.0
# 3         24.0
# 4         24.0
# ..         ...
# 581       24.0
# 582       24.0
# 583       24.0
# 584       24.0
# 587       24.0
#
# [555 rows x 24 columns]

# %%
df_03 = pd.read_csv("Raleigh2020DF.csv")
#print(df_01.count())
#drop the null rows
df_03 = df_03.dropna()
print(df_03['Site Name'].unique())
# Out:
# ['Millbrook School']

# %%
#print(df_03.head())
#pd.read_csv(io.StringIO(df_01.to_csv(index=False)))
test3_df=df_03.iloc[:,1:]
test3_df
# Out:
#             Site Name       Date  DMean PM10  PM_UNITS  PM10 AQI  PM-WEIGHT  \
# 40   Millbrook School  1/21/2020         6.0  ug/m3 SC       6.0        1.0
# 41   Millbrook School  1/21/2020         7.0  ug/m3 SC       6.0        1.0
# 42   Millbrook School  1/22/2020        10.0  ug/m3 SC       9.0        1.0
# 43   Millbrook School  1/22/2020        12.0  ug/m3 SC      11.0        1.0
# 44   Millbrook School  1/23/2020        14.0  ug/m3 SC      13.0        1.0
# ..                ...        ...         ...       ...       ...        ...
# 693  Millbrook School  3/30/2020        12.0  ug/m3 SC      11.0        1.0
# 694  Millbrook School  3/31/2020        11.0  ug/m3 SC      10.0        1.0
# 695  Millbrook School   4/1/2020         5.0  ug/m3 SC       5.0        1.0
# 696  Millbrook School   4/2/2020         8.0  ug/m3 SC       7.0        1.0
# 697  Millbrook School   4/3/2020         9.0  ug/m3 SC       8.0        1.0
#
#            LAt        Lng  DMax NO2 NO2 Units  ...  Ozone AQI  OZONE-WEIGHT  \
# 40   35.856111 -78.574167       6.4       ppb  ...       37.0          17.0
# 41   35.856111 -78.574167       6.4       ppb  ...       37.0          17.0
# 42   35.856111 -78.574167      13.6       ppb  ...       34.0          17.0
# 43   35.856111 -78.574167      13.6       ppb  ...       34.0          17.0
# 44   35.856111 -78.574167      13.8       ppb  ...       29.0          17.0
# ..         ...        ...       ...       ...  ...        ...           ...
# 693  35.856111 -78.574167       3.7       ppb  ...       46.0          17.0
# 694  35.856111 -78.574167       2.9       ppb  ...       31.0          17.0
# 695  35.856111 -78.574167       6.2       ppb  ...       37.0          17.0
# 696  35.856111 -78.574167       3.3       ppb  ...       41.0          17.0
# 697  35.856111 -78.574167       6.2       ppb  ...       46.0          17.0
#
#      DMax SO2 SO2 Units  SO2 AQI  SO2-WEIGHT  DMax CO CO Units  CO AQI  \
# 40        1.3       ppb      1.0        23.0      0.2      ppm     2.0
# 41        1.3       ppb      1.0        23.0      0.2      ppm     2.0
# 42        1.7       ppb      1.0        23.0      0.3      ppm     3.0
# 43        1.7       ppb      1.0        23.0      0.3      ppm     3.0
# 44        0.5       ppb      0.0        23.0      0.3      ppm     3.0
# ..        ...       ...      ...         ...      ...      ...     ...
# 693       0.1       ppb      0.0        23.0      0.2      ppm     2.0
# 694       0.7       ppb      0.0        23.0      0.2      ppm     2.0
# 695       0.1       ppb      0.0        23.0      0.2      ppm     2.0
# 696       0.3       ppb      0.0        23.0      0.2      ppm     2.0
# 697       0.3       ppb      0.0        23.0      0.2      ppm     2.0
#
#      CO-WEIGHT
# 40        24.0
# 41        24.0
# 42        24.0
# 43        24.0
# 44        24.0
# ..         ...
# 693       24.0
# 694       24.0
# 695       24.0
# 696       24.0
# 697       24.0
#
# [602 rows x 24 columns]

# %%
AllData=pd.DataFrame()
AllData=AllData.append(test_df)

# %%
AllData=AllData.append(test2_df)

# %%
AllData=AllData.append(test3_df)

# %%
AllData.to_csv("RaleighMerged.csv")

# %%
AllData
# Out:
#             Site Name       Date  DMean PM10  PM_UNITS  PM10 AQI  PM-WEIGHT  \
# 0    Millbrook School  8/27/2016         7.0  ug/m3 SC       6.0        1.0
# 1    Millbrook School  8/28/2016         7.0  ug/m3 SC       6.0        1.0
# 2    Millbrook School  8/28/2016        15.0  ug/m3 SC      14.0        1.0
# 3    Millbrook School  8/28/2016        15.0  ug/m3 SC      14.0        1.0
# 5    Millbrook School   9/2/2016         9.0  ug/m3 SC       8.0        1.0
# ..                ...        ...         ...       ...       ...        ...
# 693  Millbrook School  3/30/2020        12.0  ug/m3 SC      11.0        1.0
# 694  Millbrook School  3/31/2020        11.0  ug/m3 SC      10.0        1.0
# 695  Millbrook School   4/1/2020         5.0  ug/m3 SC       5.0        1.0
# 696  Millbrook School   4/2/2020         8.0  ug/m3 SC       7.0        1.0
# 697  Millbrook School   4/3/2020         9.0  ug/m3 SC       8.0        1.0
#
#            LAt        Lng  DMax NO2 NO2 Units  ...  Ozone AQI  OZONE-WEIGHT  \
# 0    35.856111 -78.574167       8.0       ppb  ...       46.0          17.0
# 1    35.856111 -78.574167       2.0       ppb  ...       44.0          17.0
# 2    35.856111 -78.574167       2.0       ppb  ...       44.0          17.0
# 3    35.856111 -78.574167       2.0       ppb  ...       44.0          17.0
# 5    35.856111 -78.574167       6.7       ppb  ...       27.0          17.0
# ..         ...        ...       ...       ...  ...        ...           ...
# 693  35.856111 -78.574167       3.7       ppb  ...       46.0          17.0
# 694  35.856111 -78.574167       2.9       ppb  ...       31.0          17.0
# 695  35.856111 -78.574167       6.2       ppb  ...       37.0          17.0
# 696  35.856111 -78.574167       3.3       ppb  ...       41.0          17.0
# 697  35.856111 -78.574167       6.2       ppb  ...       46.0          17.0
#
#      DMax SO2 SO2 Units  SO2 AQI  SO2-WEIGHT  DMax CO CO Units  CO AQI  \
# 0         0.3       ppb      0.0        23.0      0.3      ppm     3.0
# 1         0.2       ppb      0.0        23.0      0.2      ppm     2.0
# 2         0.2       ppb      0.0        23.0      0.2      ppm     2.0
# 3         0.2       ppb      0.0        23.0      0.2      ppm     2.0
# 5         0.2       ppb      0.0        23.0      0.2      ppm     2.0
# ..        ...       ...      ...         ...      ...      ...     ...
# 693       0.1       ppb      0.0        23.0      0.2      ppm     2.0
# 694       0.7       ppb      0.0        23.0      0.2      ppm     2.0
# 695       0.1       ppb      0.0        23.0      0.2      ppm     2.0
# 696       0.3       ppb      0.0        23.0      0.2      ppm     2.0
# 697       0.3       ppb      0.0        23.0      0.2      ppm     2.0
#
#      CO-WEIGHT
# 0         24.0
# 1         24.0
# 2         24.0
# 3         24.0
# 5         24.0
# ..         ...
# 693       24.0
# 694       24.0
# 695       24.0
# 696       24.0
# 697       24.0
#
# [1421 rows x 24 columns]

# %%
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
#files 
Cheyenne_PM = "2016-Cheyenne-PM10.csv"
ElPaso_PM = "2016-ElPaso-PM10.csv"
LA_PM = "2016-LA-PM10.csv"
NY_PM = "2016-NY-PM10.csv"
Raleigh_PM = "2016-Raleigh-PM10.csv"
#Seattle_PM = "2016-Seattle-PM10.csv"

ch_csv="CH2016.csv"
ep_csv="EP2016.csv"
la_csv="LA2016.csv"
ny_csv="Y2016.csv"
ra_csv="RA2016.csv"

# %% [markdown]
# #files
# Cheyenne_PM = "2018-Cheyenne-PM10.csv"
# ElPaso_PM = "2018-ElPaso-PM10.csv"
# LA_PM = "2018-LA-PM10.csv"
# NY_PM = "2018-NY-PM10.csv"
# Raleigh_PM = "2018-Raleigh-PM10.csv"
# Seattle_PM = "2018-Seattle-PM10.csv"
#
# ch_csv="CH2018.csv"
# ep_csv="EP2018.csv"
# la_csv="LA2018.csv"
# ny_csv="Y2018.csv"
# ra_csv="RA2018.csv"
# se_csv="SE2018.csv"

# %% [markdown]
# Cheyenne_PM = "2020-Cheyenne-PM10.csv"
# ElPaso_PM = "2020-ElPaso-PM10.csv"
# LA_PM = "2020-LA-PM10.csv"
# NY_PM = "2020-NY-PM10.csv"
# Raleigh_PM = "2020-Raleigh-PM10.csv"
# Seattle_PM = "2020-Seattle-PM10.csv"
#
# ch_csv="CH2020.csv"
# ep_csv="EP2020.csv"
# la_csv="LA2020.csv"
# ny_csv="Y2020.csv"
# ra_csv="RA2020.csv"
# se_csv="SE2020.csv"

# %%
#Read into Pandas Dataframe
df_CH = pd.read_csv(Cheyenne_PM)
df_EP = pd.read_csv(ElPaso_PM)
df_LA = pd.read_csv(LA_PM)
df_NY = pd.read_csv(NY_PM)
df_RA = pd.read_csv(Raleigh_PM)
#df_SE = pd.read_csv(Seattle_PM)

# %%
df_CH.dropna()
df_CH.head()
# Out:
#         Date Source    Site ID  POC  Daily Mean PM10 Concentration     UNITS  \
# 0   1/1/2016    AQS  560210001    1                              3  ug/m3 SC
# 1   1/7/2016    AQS  560210001    1                              7  ug/m3 SC
# 2  1/13/2016    AQS  560210001    1                              3  ug/m3 SC
# 3  1/19/2016    AQS  560210001    1                              3  ug/m3 SC
# 4  1/25/2016    AQS  560210001    1                              2  ug/m3 SC
#
#    DAILY_AQI_VALUE            Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0                3  Cheyenne SLAMS site                1               100
# 1                6  Cheyenne SLAMS site                1               100
# 2                3  Cheyenne SLAMS site                1               100
# 3                3  Cheyenne SLAMS site                1               100
# 4                2  Cheyenne SLAMS site                1               100
#
# ...

# %%
df_CH=df_CH[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Mean PM10 Concentration','DAILY_AQI_VALUE']]
df_CH.to_csv(ch_csv)

# %%
#df_SE=df_SE[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Mean PM10 Concentration','DAILY_AQI_VALUE']]
df_EP=df_EP[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Mean PM10 Concentration','DAILY_AQI_VALUE']]
df_LA=df_LA[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Mean PM10 Concentration','DAILY_AQI_VALUE']]
df_NY=df_NY[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Mean PM10 Concentration','DAILY_AQI_VALUE']]
df_RA=df_RA[['Date','Site Name','SITE_LATITUDE','SITE_LONGITUDE','Daily Mean PM10 Concentration','DAILY_AQI_VALUE']]

# %%
#df_CH['Site Name'].unique()

# %%
df_SE.dropna()
df_SE['Site Name'].unique()
df_SE.to_csv(se_csv)

# %%
df_EP.dropna()
df_EP['Site Name'].unique()
df_EP.to_csv(ep_csv)

# %%
df_LA.dropna()
df_LA['Site Name'].unique()
df_LA.to_csv(la_csv)

# %%
df_NY.dropna()
df_NY['Site Name'].unique()

df_NY.to_csv(ny_csv ,encoding='ISO-8859-1')

# %%
df_RA.dropna()
df_RA['Site Name'].unique()
df_RA.to_csv(ra_csv)

# %%
#files are cleaned - merge manually
